# %%
""" 
Detailed analyses of line2 e4xperiments 
over last few days.
- Addressing a verity of questions related to genraelzation.
"""

# %%
# %load_ext autoreload
# %autoreload 2

# %cd ..
# Out:
# /data1/code/python/drawmonkey

# %%
from tools.utils import * 
from tools.plots import *
from tools.analy import *
from tools.calc import *
from tools.analyplot import *
from tools.preprocess import *
from tools.dayanalysis import *

from pythonlib.drawmodel.analysis import *
from pythonlib.tools.stroketools import *
# Out:
# NOTE: need to not overwrite strokes_all_task, because then the orders saved will stop being accurate. Modify

# %%
animal = "Pancho"
expt = "lines2"
date = 200908
session = 1

fd = loadSingleData(animal, date, expt, session, resave_as_dict=False, load_resaved_data=True, 
                          resave_overwrite=False)

# %%
SAVEDIR = f"{fd['params']['figuredir_notebook']}/analysis_line2_090720/{animal}_{date}_{session}"
import os
os.makedirs(SAVEDIR, exist_ok=True)

# %%
# Out:
# did not find any glob match to /data2/animals/Pancho/200903/200903_*_lines2_Pancho_0.h5!!
# - No h5 file for Pancho, 200903, lines2, 0 - returning None!
# found one matching filename: ['/data2/animals/Pancho/200903/200903_150327_lines2_Pancho_1.h5']
# found one matching filename: ['/data2/animals/Pancho/200903/200903_150327_lines2_Pancho_1.pkl']
# -- loaded presaved data: /data2/animals/Pancho/200903/200903_150327_lines2_Pancho_1.pkl
# appending fd for sess 1
# did not find any glob match to /data2/animals/Pancho/200903/200903_*_lines2_Pancho_2.h5!!
# - No h5 file for Pancho, 200903, lines2, 2 - returning None!
# did not find any glob match to /data2/animals/Pancho/200903/200903_*_lines2_Pancho_3.h5!!
# - No h5 file for Pancho, 200903, lines2, 3 - returning None!
# did not find any glob match to /data2/animals/Pancho/200903/200903_*_lines2_Pancho_4.h5!!
# - No h5 file for Pancho, 200903, lines2, 4 - returning None!
# did not find any glob match to /data2/animals/Pancho/200903/200903_*_lines2_Pancho_5.h5!!
# - No h5 file for Pancho, 200903, lines2, 5 - returning None!
# did not find any glob match to /data2/animals/Pancho/200903/200903_*_lines2_Pancho_6.h5!!
# - No h5 file for Pancho, 200903, lines2, 6 - returning None!
# did not find any glob match to /data2/animals/Pancho/200903/200903_*_lines2_Pancho_7.h5!!
# - No h5 file for Pancho, 200903, lines2, 7 - returning None!
# did not find any glob match to /data2/animals/Pancho/200903/200903_*_lines2_Pancho_8.h5!!
# - No h5 file for Pancho, 200903, lines2, 8 - returning None!
# did not find any glob match to /data2/animals/Pancho/200903/200903_*_lines2_Pancho_9.h5!!
# - No h5 file for Pancho, 200903, lines2, 9 - returning None!
# did not find any glob match to /data2/animals/Pancho/200904/200904_*_lines2_Pancho_0.h5!!
# - No h5 file for Pancho, 200904, lines2, 0 - returning None!
# found one matching filename: ['/data2/animals/Pancho/200904/200904_145752_lines2_Pancho_1.h5']
# found one matching filename: ['/data2/animals/Pancho/200904/200904_145752_lines2_Pancho_1.pkl']
# -- loaded presaved data: /data2/animals/Pancho/200904/200904_145752_lines2_Pancho_1.pkl
# appending fd for sess 1
# found one matching filename: ['/data2/animals/Pancho/200904/200904_170126_lines2_Pancho_2.h5']
# found one matching filename: ['/data2/animals/Pancho/200904/200904_170126_lines2_Pancho_2.pkl']
# -- loaded presaved data: /data2/animals/Pancho/200904/200904_170126_lines2_Pancho_2.pkl
# appending fd for sess 2
# did not find any glob match to /data2/animals/Pancho/200904/200904_*_lines2_Pancho_3.h5!!
# - No h5 file for Pancho, 200904, lines2, 3 - returning None!
# did not find any glob match to /data2/animals/Pancho/200904/200904_*_lines2_Pancho_4.h5!!
# - No h5 file for Pancho, 200904, lines2, 4 - returning None!
# did not find any glob match to /data2/animals/Pancho/200904/200904_*_lines2_Pancho_5.h5!!
# - No h5 file for Pancho, 200904, lines2, 5 - returning None!
# did not find any glob match to /data2/animals/Pancho/200904/200904_*_lines2_Pancho_6.h5!!
# - No h5 file for Pancho, 200904, lines2, 6 - returning None!
# did not find any glob match to /data2/animals/Pancho/200904/200904_*_lines2_Pancho_7.h5!!
# - No h5 file for Pancho, 200904, lines2, 7 - returning None!
# did not find any glob match to /data2/animals/Pancho/200904/200904_*_lines2_Pancho_8.h5!!
# - No h5 file for Pancho, 200904, lines2, 8 - returning None!
# did not find any glob match to /data2/animals/Pancho/200904/200904_*_lines2_Pancho_9.h5!!
# - No h5 file for Pancho, 200904, lines2, 9 - returning None!
# did not find any glob match to /data2/animals/Pancho/200905/200905_*_lines2_Pancho_0.h5!!
# - No h5 file for Pancho, 200905, lines2, 0 - returning None!
# found one matching filename: ['/data2/animals/Pancho/200905/200905_153000_lines2_Pancho_1.h5']
# found one matching filename: ['/data2/animals/Pancho/200905/200905_153000_lines2_Pancho_1.pkl']
# -- loaded presaved data: /data2/animals/Pancho/200905/200905_153000_lines2_Pancho_1.pkl
# appending fd for sess 1
# did not find any glob match to /data2/animals/Pancho/200905/200905_*_lines2_Pancho_2.h5!!
# - No h5 file for Pancho, 200905, lines2, 2 - returning None!
# did not find any glob match to /data2/animals/Pancho/200905/200905_*_lines2_Pancho_3.h5!!
# - No h5 file for Pancho, 200905, lines2, 3 - returning None!
# did not find any glob match to /data2/animals/Pancho/200905/200905_*_lines2_Pancho_4.h5!!
# - No h5 file for Pancho, 200905, lines2, 4 - returning None!
# did not find any glob match to /data2/animals/Pancho/200905/200905_*_lines2_Pancho_5.h5!!
# - No h5 file for Pancho, 200905, lines2, 5 - returning None!
# did not find any glob match to /data2/animals/Pancho/200905/200905_*_lines2_Pancho_6.h5!!
# - No h5 file for Pancho, 200905, lines2, 6 - returning None!
# did not find any glob match to /data2/animals/Pancho/200905/200905_*_lines2_Pancho_7.h5!!
# - No h5 file for Pancho, 200905, lines2, 7 - returning None!
# did not find any glob match to /data2/animals/Pancho/200905/200905_*_lines2_Pancho_8.h5!!
# - No h5 file for Pancho, 200905, lines2, 8 - returning None!
# did not find any glob match to /data2/animals/Pancho/200905/200905_*_lines2_Pancho_9.h5!!
# - No h5 file for Pancho, 200905, lines2, 9 - returning None!
# did not find any glob match to /data2/animals/Pancho/200906/200906_*_lines2_Pancho_0.h5!!
# - No h5 file for Pancho, 200906, lines2, 0 - returning None!
# found one matching filename: ['/data2/animals/Pancho/200906/200906_152340_lines2_Pancho_1.h5']
# found one matching filename: ['/data2/animals/Pancho/200906/200906_152340_lines2_Pancho_1.pkl']
# -- loaded presaved data: /data2/animals/Pancho/200906/200906_152340_lines2_Pancho_1.pkl
# appending fd for sess 1
# did not find any glob match to /data2/animals/Pancho/200906/200906_*_lines2_Pancho_2.h5!!
# - No h5 file for Pancho, 200906, lines2, 2 - returning None!
# did not find any glob match to /data2/animals/Pancho/200906/200906_*_lines2_Pancho_3.h5!!
# - No h5 file for Pancho, 200906, lines2, 3 - returning None!
# did not find any glob match to /data2/animals/Pancho/200906/200906_*_lines2_Pancho_4.h5!!
# - No h5 file for Pancho, 200906, lines2, 4 - returning None!
# did not find any glob match to /data2/animals/Pancho/200906/200906_*_lines2_Pancho_5.h5!!
# - No h5 file for Pancho, 200906, lines2, 5 - returning None!
# did not find any glob match to /data2/animals/Pancho/200906/200906_*_lines2_Pancho_6.h5!!
# - No h5 file for Pancho, 200906, lines2, 6 - returning None!
# did not find any glob match to /data2/animals/Pancho/200906/200906_*_lines2_Pancho_7.h5!!
# - No h5 file for Pancho, 200906, lines2, 7 - returning None!
# did not find any glob match to /data2/animals/Pancho/200906/200906_*_lines2_Pancho_8.h5!!
# - No h5 file for Pancho, 200906, lines2, 8 - returning None!
# did not find any glob match to /data2/animals/Pancho/200906/200906_*_lines2_Pancho_9.h5!!
# - No h5 file for Pancho, 200906, lines2, 9 - returning None!
# ===== SUMMARY
# --
# Pancho-200903-1: ntrials: 976
#
# --
# Pancho-200904-1: ntrials: 404
#
# --
# Pancho-200904-2: ntrials: 431
#
# --
# Pancho-200905-1: ntrials: 791
#
# --
# Pancho-200906-1: ntrials: 835

# %% [markdown]
# # ACROSS-DAY ANALYSIS (SINGLE ANIMAL)

# %%
# Plot same task across days

# 1) Load data across days
from pythonlib.tools.datetools import getDateList

sdate = 200903
edate = 200907
datelist = getDateList(sdate, edate)

dattoget = []
animal = "Red"
expt = "lines2"
for d in datelist:
    dattoget.append([expt, animal, d])

FD = loadMultData(dattoget)
# Out:
# did not find any glob match to /data2/animals/Red/200903/200903_*_lines2_Red_0.h5!!
# - No h5 file for Red, 200903, lines2, 0 - returning None!
# found one matching filename: ['/data2/animals/Red/200903/200903_144042_lines2_Red_1.h5']
# found one matching filename: ['/data2/animals/Red/200903/200903_144042_lines2_Red_1.pkl']
# -- loaded presaved data: /data2/animals/Red/200903/200903_144042_lines2_Red_1.pkl
# appending fd for sess 1
# found one matching filename: ['/data2/animals/Red/200903/200903_150114_lines2_Red_2.h5']
# found one matching filename: ['/data2/animals/Red/200903/200903_150114_lines2_Red_2.pkl']
# -- loaded presaved data: /data2/animals/Red/200903/200903_150114_lines2_Red_2.pkl
# appending fd for sess 2
# found one matching filename: ['/data2/animals/Red/200903/200903_151646_lines2_Red_3.h5']
# found one matching filename: ['/data2/animals/Red/200903/200903_151646_lines2_Red_3.pkl']
# -- loaded presaved data: /data2/animals/Red/200903/200903_151646_lines2_Red_3.pkl
# appending fd for sess 3
# did not find any glob match to /data2/animals/Red/200903/200903_*_lines2_Red_4.h5!!
# - No h5 file for Red, 200903, lines2, 4 - returning None!
# did not find any glob match to /data2/animals/Red/200903/200903_*_lines2_Red_5.h5!!
# - No h5 file for Red, 200903, lines2, 5 - returning None!
# did not find any glob match to /data2/animals/Red/200903/200903_*_lines2_Red_6.h5!!
# - No h5 file for Red, 200903, lines2, 6 - returning None!
# did not find any glob match to /data2/animals/Red/200903/200903_*_lines2_Red_7.h5!!
# - No h5 file for Red, 200903, lines2, 7 - returning None!
# did not find any glob match to /data2/animals/Red/200903/200903_*_lines2_Red_8.h5!!
# - No h5 file for Red, 200903, lines2, 8 - returning None!
# did not find any glob match to /data2/animals/Red/200903/200903_*_lines2_Red_9.h5!!
# - No h5 file for Red, 200903, lines2, 9 - returning None!
# did not find any glob match to /data2/animals/Red/200904/200904_*_lines2_Red_0.h5!!
# - No h5 file for Red, 200904, lines2, 0 - returning None!
# found one matching filename: ['/data2/animals/Red/200904/200904_144016_lines2_Red_1.h5']
# found one matching filename: ['/data2/animals/Red/200904/200904_144016_lines2_Red_1.pkl']
# -- loaded presaved data: /data2/animals/Red/200904/200904_144016_lines2_Red_1.pkl
# appending fd for sess 1
# found one matching filename: ['/data2/animals/Red/200904/200904_163904_lines2_Red_2.h5']
# found one matching filename: ['/data2/animals/Red/200904/200904_163904_lines2_Red_2.pkl']
# -- loaded presaved data: /data2/animals/Red/200904/200904_163904_lines2_Red_2.pkl
# appending fd for sess 2
# did not find any glob match to /data2/animals/Red/200904/200904_*_lines2_Red_3.h5!!
# - No h5 file for Red, 200904, lines2, 3 - returning None!
# did not find any glob match to /data2/animals/Red/200904/200904_*_lines2_Red_4.h5!!
# - No h5 file for Red, 200904, lines2, 4 - returning None!
# did not find any glob match to /data2/animals/Red/200904/200904_*_lines2_Red_5.h5!!
# - No h5 file for Red, 200904, lines2, 5 - returning None!
# did not find any glob match to /data2/animals/Red/200904/200904_*_lines2_Red_6.h5!!
# - No h5 file for Red, 200904, lines2, 6 - returning None!
# did not find any glob match to /data2/animals/Red/200904/200904_*_lines2_Red_7.h5!!
# - No h5 file for Red, 200904, lines2, 7 - returning None!
# did not find any glob match to /data2/animals/Red/200904/200904_*_lines2_Red_8.h5!!
# - No h5 file for Red, 200904, lines2, 8 - returning None!
# did not find any glob match to /data2/animals/Red/200904/200904_*_lines2_Red_9.h5!!
# - No h5 file for Red, 200904, lines2, 9 - returning None!
# did not find any glob match to /data2/animals/Red/200905/200905_*_lines2_Red_0.h5!!
# - No h5 file for Red, 200905, lines2, 0 - returning None!
# found one matching filename: ['/data2/animals/Red/200905/200905_150806_lines2_Red_1.h5']
# found one matching filename: ['/data2/animals/Red/200905/200905_150806_lines2_Red_1.pkl']
# -- loaded presaved data: /data2/animals/Red/200905/200905_150806_lines2_Red_1.pkl
# appending fd for sess 1
# found one matching filename: ['/data2/animals/Red/200905/200905_154753_lines2_Red_2.h5']
# found one matching filename: ['/data2/animals/Red/200905/200905_154753_lines2_Red_2.pkl']
# -- loaded presaved data: /data2/animals/Red/200905/200905_154753_lines2_Red_2.pkl
# appending fd for sess 2
# found one matching filename: ['/data2/animals/Red/200905/200905_164750_lines2_Red_3.h5']
# found one matching filename: ['/data2/animals/Red/200905/200905_164750_lines2_Red_3.pkl']
# -- loaded presaved data: /data2/animals/Red/200905/200905_164750_lines2_Red_3.pkl
# appending fd for sess 3
# did not find any glob match to /data2/animals/Red/200905/200905_*_lines2_Red_4.h5!!
# - No h5 file for Red, 200905, lines2, 4 - returning None!
# did not find any glob match to /data2/animals/Red/200905/200905_*_lines2_Red_5.h5!!
# - No h5 file for Red, 200905, lines2, 5 - returning None!
# did not find any glob match to /data2/animals/Red/200905/200905_*_lines2_Red_6.h5!!
# - No h5 file for Red, 200905, lines2, 6 - returning None!
# did not find any glob match to /data2/animals/Red/200905/200905_*_lines2_Red_7.h5!!
# - No h5 file for Red, 200905, lines2, 7 - returning None!
# did not find any glob match to /data2/animals/Red/200905/200905_*_lines2_Red_8.h5!!
# - No h5 file for Red, 200905, lines2, 8 - returning None!
# did not find any glob match to /data2/animals/Red/200905/200905_*_lines2_Red_9.h5!!
# - No h5 file for Red, 200905, lines2, 9 - returning None!
# did not find any glob match to /data2/animals/Red/200906/200906_*_lines2_Red_0.h5!!
# - No h5 file for Red, 200906, lines2, 0 - returning None!
# found one matching filename: ['/data2/animals/Red/200906/200906_151208_lines2_Red_1.h5']
# found one matching filename: ['/data2/animals/Red/200906/200906_151208_lines2_Red_1.pkl']
# -- loaded presaved data: /data2/animals/Red/200906/200906_151208_lines2_Red_1.pkl
# appending fd for sess 1
# found one matching filename: ['/data2/animals/Red/200906/200906_160803_lines2_Red_2.h5']
# found one matching filename: ['/data2/animals/Red/200906/200906_160803_lines2_Red_2.pkl']
# -- loaded presaved data: /data2/animals/Red/200906/200906_160803_lines2_Red_2.pkl
# appending fd for sess 2
# did not find any glob match to /data2/animals/Red/200906/200906_*_lines2_Red_3.h5!!
# - No h5 file for Red, 200906, lines2, 3 - returning None!
# did not find any glob match to /data2/animals/Red/200906/200906_*_lines2_Red_4.h5!!
# - No h5 file for Red, 200906, lines2, 4 - returning None!
# did not find any glob match to /data2/animals/Red/200906/200906_*_lines2_Red_5.h5!!
# - No h5 file for Red, 200906, lines2, 5 - returning None!
# did not find any glob match to /data2/animals/Red/200906/200906_*_lines2_Red_6.h5!!
# - No h5 file for Red, 200906, lines2, 6 - returning None!
# did not find any glob match to /data2/animals/Red/200906/200906_*_lines2_Red_7.h5!!
# - No h5 file for Red, 200906, lines2, 7 - returning None!
# did not find any glob match to /data2/animals/Red/200906/200906_*_lines2_Red_8.h5!!
# - No h5 file for Red, 200906, lines2, 8 - returning None!
# did not find any glob match to /data2/animals/Red/200906/200906_*_lines2_Red_9.h5!!
# - No h5 file for Red, 200906, lines2, 9 - returning None!
# did not find any glob match to /data2/animals/Red/200907/200907_*_lines2_Red_0.h5!!
# - No h5 file for Red, 200907, lines2, 0 - returning None!
# found one matching filename: ['/data2/animals/Red/200907/200907_145242_lines2_Red_1.h5']
# found one matching filename: ['/data2/animals/Red/200907/200907_145242_lines2_Red_1.pkl']
# -- loaded presaved data: /data2/animals/Red/200907/200907_145242_lines2_Red_1.pkl
# appending fd for sess 1
# did not find any glob match to /data2/animals/Red/200907/200907_*_lines2_Red_2.h5!!
# - No h5 file for Red, 200907, lines2, 2 - returning None!
# did not find any glob match to /data2/animals/Red/200907/200907_*_lines2_Red_3.h5!!
# - No h5 file for Red, 200907, lines2, 3 - returning None!
# did not find any glob match to /data2/animals/Red/200907/200907_*_lines2_Red_4.h5!!
# - No h5 file for Red, 200907, lines2, 4 - returning None!
# did not find any glob match to /data2/animals/Red/200907/200907_*_lines2_Red_5.h5!!
# - No h5 file for Red, 200907, lines2, 5 - returning None!
# did not find any glob match to /data2/animals/Red/200907/200907_*_lines2_Red_6.h5!!
# - No h5 file for Red, 200907, lines2, 6 - returning None!
# did not find any glob match to /data2/animals/Red/200907/200907_*_lines2_Red_7.h5!!
# - No h5 file for Red, 200907, lines2, 7 - returning None!
# did not find any glob match to /data2/animals/Red/200907/200907_*_lines2_Red_8.h5!!
# - No h5 file for Red, 200907, lines2, 8 - returning None!
# did not find any glob match to /data2/animals/Red/200907/200907_*_lines2_Red_9.h5!!
# - No h5 file for Red, 200907, lines2, 9 - returning None!
# ===== SUMMARY
# --
# Red-200903-1: ntrials: 66
#
# --
# Red-200903-2: ntrials: 62
#
# --
# Red-200903-3: ntrials: 989
#
# --
# Red-200904-1: ntrials: 585
#
# --
# Red-200904-2: ntrials: 571
#
# --
# Red-200905-1: ntrials: 157
#
# --
# Red-200905-2: ntrials: 263
#
# --
# Red-200905-3: ntrials: 486
#
# --
# Red-200906-1: ntrials: 228
#
# --
# Red-200906-2: ntrials: 643
#
# --
# Red-200907-1: ntrials: 1136

# %%
# saving dir
SAVEDIR = f"{FD[0]['fd']['params']['figuredir_notebook']}/analysis_line2_090720/multday_{animal}_{sdate}_to_{edate}"
import os
os.makedirs(SAVEDIR, exist_ok=True)
print(f"saving at {SAVEDIR}")
# Out:
# saving at /data2/analyses/notebook/analysis_line2_090720/multday_Red_200903_to_200907

# %%
# ==== Flatten all trials across days x animals
# for each trial collect relevant information

from analysis.line2 import PROBEDATfromFD

PROBEDAT = PROBEDATfromFD(FD)
# Out:
# got 65 total trials
# got 61 total trials
# got 988 total trials
# got 585 total trials
# got 570 total trials
# got 157 total trials
# got 263 total trials
# got 485 total trials
# got 227 total trials
# got 642 total trials
# got 1135 total trials

# %%
# === Focus on a single task. Plot its trajectory and compare difefrent days

# - 1) visualize candidate tasks
# a) first, only consider fixed tasks
print("--- list of fixed tasks:")
T = sorted(set([P["unique_task_name"] for P in PROBEDAT if P["random_task"]==False]))
[print(t) for t in T];
# Out:
# --- list of fixed tasks:
# 3line_10-resynth-Red_200903_3-1-1
# 3line_10-resynth-Red_200903_3-1-63
# 3line_3-resynth-Red_200903_3-1-12
# 3line_4-resynth-Red_200903_3-1-19
# 3line_4-resynth-Red_200903_3-1-66
# 3line_4-resynth-Red_200903_3-1-85
# 3line_5-resynth-Red_200903_3-1-65
# 3line_6-resynth-Red_200903_3-1-8
# 3line_7-resynth-Red_200903_3-1-80
# 3line_8-resynth-Red_200903_3-1-6
# 3line_8-resynth-Red_200903_3-1-71
# 3line_8-resynth-Red_200903_3-1-82
# 3line_9-resynth-Red_200903_3-1-14
# 3line_9-resynth-Red_200903_3-1-75
# 4_1-protype
# 4_2-protype
# 4_3-protype
# 4_4-protype
# 4_5-protype
# 4_6-protype
# 4_7-protype
# C_1-protype
# C_2-protype
# F_1-protype
# F_2-protype
# IL_1-protype
# IL_2-protype
# IL_3-protype
# IL_4-protype
# IL_5-protype
# IL_6-protype
# IL_7-protype
# IL_8-protype
# K_1-protype
# K_2-protype
# N_1-protype
# N_2-protype
# P_1-protype
# P_2-protype
# P_3-protype
# P_4-protype
# S_1-protype
# S_2-protype
# h_1-protype
# h_2-protype
# linePlusLv2_11-savedset-1
# linePlusLv2_119-savedset-1
# linePlusLv2_13-savedset-1
# linePlusLv2_141-savedset-1
# linePlusLv2_155-savedset-1
# linePlusLv2_16-savedset-1
# linePlusLv2_18-savedset-1
# linePlusLv2_22-savedset-1
# linePlusLv2_25-savedset-1
# linePlusLv2_26-savedset-1
# linePlusLv2_3-savedset-1
# linePlusLv2_33-savedset-1
# linePlusLv2_44-savedset-1
# linePlusLv2_45-savedset-1
# linePlusLv2_46-savedset-1
# linePlusLv2_5-savedset-1
# linePlusLv2_51-savedset-1
# linePlusLv2_54-savedset-1
# linePlusLv2_58-savedset-1
# linePlusLv2_59-savedset-1
# linePlusLv2_61-savedset-1
# linePlusLv2_64-savedset-1
# linePlusLv2_69-savedset-1
# linePlusLv2_7-savedset-1
# linePlusLv2_76-savedset-1
# linePlusLv2_79-savedset-1
# linePlusLv2_80-savedset-1
# linePlusLv2_83-savedset-1
# linePlusLv2_94-savedset-1
# linePlusLv2_95-savedset-1
# linePlusLv2_97-savedset-1
# teepee_1-protype
# teepee_2-protype
# teepee_3-protype
# teepee_4-protype
# triangle_1-protype
# tristar_1-protype

# %%
# get all fixed tasks of a particular kind
kindlist = set([P["kind"] for P in PROBEDAT if P["random_task"]==False])

task_per_kind = {}
for kind in kindlist:
    tasklist = set([P["unique_task_name"] for P in PROBEDAT if P["kind"]==kind])
    task_per_kind[kind]=sorted(tasklist)
    
print("tasks per kind found")
for k, v in task_per_kind.items():
    print("----")
    print(f"=={k}")
    [print(vv) for vv in v]
# Out:
# tasks per kind found
# ----
# ==probe1_nostrokeconstraint
# F_1-protype
# F_2-protype
# N_1-protype
# N_2-protype
# h_1-protype
# h_2-protype
# tristar_1-protype
# ----
# ==probe3_hdpos
# 3line_10-resynth-Red_200903_3-1-1
# 3line_10-resynth-Red_200903_3-1-63
# 3line_3-resynth-Red_200903_3-1-12
# 3line_4-resynth-Red_200903_3-1-19
# 3line_4-resynth-Red_200903_3-1-66
# 3line_4-resynth-Red_200903_3-1-85
# 3line_5-resynth-Red_200903_3-1-65
# 3line_6-resynth-Red_200903_3-1-8
# 3line_7-resynth-Red_200903_3-1-80
# 3line_8-resynth-Red_200903_3-1-6
# 3line_8-resynth-Red_200903_3-1-71
# 3line_8-resynth-Red_200903_3-1-82
# 3line_9-resynth-Red_200903_3-1-14
# 3line_9-resynth-Red_200903_3-1-75
# 4_1-protype
# 4_2-protype
# 4_3-protype
# 4_4-protype
# 4_5-protype
# 4_6-protype
# 4_7-protype
# F_1-protype
# F_2-protype
# IL_1-protype
# IL_2-protype
# IL_3-protype
# IL_4-protype
# IL_5-protype
# IL_6-protype
# IL_7-protype
# IL_8-protype
# N_1-protype
# N_2-protype
# P_1-protype
# P_2-protype
# P_3-protype
# P_4-protype
# h_1-protype
# h_2-protype
# linePlusLv2_11-savedset-1
# linePlusLv2_119-savedset-1
# linePlusLv2_13-savedset-1
# linePlusLv2_141-savedset-1
# linePlusLv2_155-savedset-1
# linePlusLv2_16-savedset-1
# linePlusLv2_18-savedset-1
# linePlusLv2_22-savedset-1
# linePlusLv2_25-savedset-1
# linePlusLv2_26-savedset-1
# linePlusLv2_3-savedset-1
# linePlusLv2_33-savedset-1
# linePlusLv2_44-savedset-1
# linePlusLv2_45-savedset-1
# linePlusLv2_46-savedset-1
# linePlusLv2_5-savedset-1
# linePlusLv2_51-savedset-1
# linePlusLv2_54-savedset-1
# linePlusLv2_58-savedset-1
# linePlusLv2_59-savedset-1
# linePlusLv2_61-savedset-1
# linePlusLv2_64-savedset-1
# linePlusLv2_69-savedset-1
# linePlusLv2_7-savedset-1
# linePlusLv2_76-savedset-1
# linePlusLv2_79-savedset-1
# linePlusLv2_80-savedset-1
# linePlusLv2_83-savedset-1
# linePlusLv2_94-savedset-1
# linePlusLv2_95-savedset-1
# linePlusLv2_97-savedset-1
# teepee_1-protype
# teepee_2-protype
# teepee_3-protype
# teepee_4-protype
# tristar_1-protype
# ----
# ==probe1_liketrain
# C_1-protype
# C_2-protype
# K_1-protype
# K_2-protype
# S_1-protype
# S_2-protype
# triangle_1-protype

# %%
plotTrialSimple(FD[4]["fd"], 103, plotver="order", post_go_only=True, use_peanut_params={'replaynum': 1, 'active': True})
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f70de31f290>, None)

# %% [markdown]
# ## PLOT - all trials, 2d grid sorted by date and task category

# %%
# == get all task stages (catregories) that have data across dates

# only keep data for fixed tasks.
PROBEDATthis = [P for P in PROBEDAT if P["random_task"]==False]
datelist = sorted(set([P["date"] for P in PROBEDATthis]))

# all categories that have fixed tasks
stagelist = set([P["task_stagecategory"] for P in PROBEDATthis if P["random_task"]==False])

# for each category, check that has data across days
if False:
    # not done - currently taking all stages
    for stage in stagelist:
        datelist = set([P["date"] for P in PROBEDATthis if P["task_stagecategory"] == stage])

# for each stage, make a 2d grid plot (date x task)
for stage in stagelist:
    tasklist = sorted(set([P["unique_task_name"] for P in PROBEDATthis if P["task_stagecategory"]==stage]))
    if len(tasklist)>50:
        assert False, "why so many tasks for this stage?"
        
    # -- Plot 2d grid, separated by days
    CAT1 = ["date", datelist]
    CAT2 = ["unique_task_name", tasklist]
    plotargs = {"zoom":True, "plotver":"order", "markersize":4, "alpha":0.25}
    # fdlist = [P["filedata"][0]() for P in PROBEDATthis]
    fdlist = None
    # fdlist = [FD[P["ii"]]["fd"] for P in PROBEDATthis]

    fig = plotTrial2dGrid(PROBEDATthis, fdlist = fdlist, cat1 = CAT1, cat2 = CAT2, ver="beh", plotargs=plotargs);
    fig.savefig(f"{SAVEDIR}/alltrials_datebycategory_beh_{stage}.pdf")
    fig = plotTrial2dGrid(PROBEDATthis, fdlist = fdlist, cat1 = CAT1, cat2 = CAT2, ver="task", plotargs=plotargs);
    fig.savefig(f"{SAVEDIR}/alltrials_datebycategory_task_{stage}.pdf")
#     assert False

# %%
# 1) clean strokes
# 2) mean 1st, second, etc
# 3) seaprate by stroke num
# 4) plot 1
# 5) plot N (matched)
# first N trials each day.

# %%
SAVEDIR
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-145-6875ccd134fb> in <module>
# ----> 1 SAVEDIR
#
# NameError: name 'SAVEDIR' is not defined

# %%
task_to_get = "C_1-protype"
task_to_get = "teepee_1-protype"

# Filter dat to only get this task
PROBEDATthis = [P for P in PROBEDAT if P["unique_task_name"]==task_to_get]
print(len(PROBEDATthis))
from pythonlib.tools.dicttools import printOverviewKeyValues
printOverviewKeyValues(PROBEDATthis)

# -- Plot over timecourse over days
# Out:
# 13
# -----
# - resynthesized_setnum (N = 1)
# None
# -----
# - random_task (N = 1)
# False
# -----
# - block (N = 1)
# 5
# -----
# - feedback_ver (N = 1)
# same_except_model
# -----
# - session (N = 1)
# 1
# -----
# - resynthesized (N = 1)
# 0
# -----
# - saved_setnum (N = 1)
# None
# === skipping feedback_ver_prms, because of Exception: <class 'Exception'>
# -----
# - resynthesized_trial (N = 1)
# None
# -----
# - expt (N = 1)
# lines2
# -----
# - constraints_to_skip (N = 1)
# lines2
# -----
# - ii (N = 3)
# 0
# 3
# 4
# -----
# - unique_task_name (N = 1)
# teepee_1-protype
# -----
# - task_stagecategory (N = 1)
# teepee
# -----
# - kind (N = 1)
# probe3_hdpos
# -----
# - resynthesized_path (N = 1)
# None
# -----
# - trial_day (N = 13)
# 448
# 129
# 447
# 681
# 682
# 588
# 269
# 270
# 369
# 244
# 474
# 286
# 159
# -----
# - resynthesized_setname (N = 1)
# None
# -----
# - tasknum (N = 1)
# 1
# -----
# - trial (N = 13)
# 288
# 289
# 608
# 480
# 481
# 263
# 170
# 399
# 751
# 305
# 625
# 752
# 143
# -----
# - prototype (N = 1)
# 1
# -----
# - probe (N = 1)
# 1
# -----
# - animal (N = 1)
# Pancho
# -----
# - date (N = 3)
# 200905
# 200903
# 200906
# {'resynthesized_setnum': {None},
#  'random_task': {False},
#  'block': {5},
#  'feedback_ver': {'same_except_model'},
#  'session': {1},
#  'resynthesized': {0},
#  'saved_setnum': {None},
#  'resynthesized_trial': {None},
#  'expt': {'lines2'},
#  'constraints_to_skip': {'lines2'},
#  'ii': {0, 3, 4},
#  'unique_task_name': {'teepee_1-protype'},
#  'task_stagecategory': {'teepee'},
#  'kind': {'probe3_hdpos'},
#  'resynthesized_path': {None},
#  'trial_day': {129,
#   159,
#   244,
#   269,
#   270,
#   286,
#   369,
#   447,
#   448,
#   474,
#   588,
#   681,
#   682},
#  'resynthesized_setname': {None},
#  'tasknum': {1},
#  'trial': {143, 170, 263, 288, 289, 305, 399, 480, 481, 608, 625, 751, 752},
#  'prototype': {1},
#  'probe': {1},
#  'animal': {'Pancho'},
#  'date': {'200903', '200905', '200906'}}

# %%
# -- Plot 2d grid, separated by days
CAT1 = ["date", []]
CAT2 = None
plotargs = {"zoom":True, "plotver":"strokes", "markersize":4, "alpha":0.25}
# fdlist = [P["filedata"][0]() for P in PROBEDATthis]
fdlist = None
# fdlist = [FD[P["ii"]]["fd"] for P in PROBEDATthis]

fig = plotTrial2dGrid(PROBEDATthis, fdlist = fdlist, cat1 = CAT1, cat2 = CAT2, ver="beh", plotargs=plotargs);
# fig.savefig(f"{SAVEDIR}/psychometric_trials_beh_{settoget}.pdf")
fig = plotTrial2dGrid(PROBEDATthis, fdlist = fdlist, cat1 = CAT1, cat2 = CAT2, ver="task", plotargs=plotargs);
# fig.savefig(f"{SAVEDIR}/psychometric_trials_task_{settoget}.pdf")

# %%
A = [("lines2", "Red", 200908),
 ("lines2", "Pancho", 200908)]

# for (expt, animal, date) in A:

#     # expt = "lines1"
#     # animal = "Red"
#     # date = 200831

#     # expt = "ESC1"
#     # animal = "Red"
#     # date = 200830

#     # simple, just try many sessions...
#     fdsessions = []
#     FD = {}
#     N = 12
#     for session in range(10):
#         fd = loadSingleData(animal, date, expt, session, resave_as_dict=False, load_resaved_data=True, 
#                           resave_overwrite=False)
#         if fd is not None:
#             print(f"appending fd for sess {session}")
#             fdsessions.append({
#                 "session": session,
#                 "fd":fd})
#             FD[session] = fd
#             if session==N-1:
#                 assert False, "got the end and still found.. you need to search for even more sessions..."

#             SAVEDIR = f"{fd['params']['figuredir_notebook']}/probes/{animal}_{date}"
#             import os
#             os.makedirs(SAVEDIR, exist_ok=True)


#     print("--- SUMMARY")
#     for f in fdsessions:
#         print(f"session: {f['session']}, ntrials: {f['fd']['params']['n_trials']}")


    # === categorize all trials based on task/probe, etc
#     probedat = []
#     ct = 0
#     for sess, fd in FD.items():
#         for t in getIndsTrials(fd):
#             if getTrialsFixationSuccess(fd, t):
#                 probe = getTrialsTaskProbeInfo(fd, t)
#                 task = getTrialsTask(fd, t)
                
# #                 print(probe)
                
#                 if getTrialsTaskIsFix(fd, t):
#                     randomtask = False
#                 else:
#                     randomtask = True
# #                 if probe["prototype"]==0 and probe["saved_setnum"] is None and probe["resynthesized"]==0:
# #                     # then this is new random task sampled each block.
# #                     randomtask = True
# #                 else:
# #                     randomtask = False

#                 if probe["probe"]==0:
#                     kind = "train"
#                 else:
#                     if probe["feedback_ver"]=="same_as_task" and randomtask==False:
#                         if probe["constraints_to_skip"]=={}:
#                             kind = "probe1_liketrain"
#                         elif "strokes" in probe["constraints_to_skip"].values():
#                             kind = "probe1_nostrokeconstraint"
#                     elif probe["feedback_ver"]=="same_as_task" and randomtask==True and probe["constraints_to_skip"]=={}:
#                         kind = "probe2_liketrain"
#                     elif probe["feedback_ver"]=="same_as_task" and randomtask==True and "strokes" in probe["constraints_to_skip"].values():
#                         kind = "probe2_nostrokeconstraint"
#                     elif probe["feedback_ver"] in ["thresh_active", "mid_reward"] and randomtask==False and "strokes" in probe["constraints_to_skip"].values():
#                         kind = "probe3"
#                     elif probe["feedback_ver"] in ["same_except_model"] and randomtask==False and "strokes" in probe["constraints_to_skip"].values():
#                         kind = "probe3_hdpos"
#                     elif probe["feedback_ver"] in ["thresh_active", "mid_reward"] and randomtask==True and "strokes" in probe["constraints_to_skip"].values():
#                         kind = "probe4"
#                     else:
#                         print(probe)
#                         assert False, "what kind is this?"

#                 probedat.append({
#                     "session":sess,
#                     "trial":t,
#                     "trial_day":ct,
#                     "kind":kind,
#                     "taskname": getTrialsUniqueTasknameGood(fd, t),
#                     "stage":task["stage"],
#                     "block":getTrialsBlock(FD[sess], t),
#                     "prototype":probe["prototype"],
#                     "constraints_to_skip":probe["constraints_to_skip"]})
#                 ct+=1


    # == for each category, list names of all tasks
    kindlist = set([p["kind"] for p in probedat])
    print("probe kinds -- trials");
    for kind in kindlist:
        print(" ")
        print(kind)
        trials = [p["trial"] for p in probedat if p["kind"]==kind]
        tasknames = [p["taskname"] for p in probedat if p["kind"]==kind]
    #     print(trials)
        print(set(tasknames))
        plt.figure()
        plt.plot(trials, tasknames)

    import seaborn as sns
    import pandas as pd
    dframe = pd.DataFrame(probedat)

    # sns.scatterplot(x="trial", y="taskname", data=dframe, hue="kind")
    fig, axes = plt.subplots(5, 1, sharex=True, squeeze=False, figsize=(28, 10))

    sns.scatterplot(x="trial_day", y="kind", data=dframe, hue="kind", ax=axes[0][0])
    sns.scatterplot(x="trial_day", y="stage", data=dframe, hue="kind", ax=axes[1][0])
    sns.scatterplot(x="trial_day", y="stage", data=dframe, hue="prototype", ax=axes[2][0])
    sns.lineplot(x="trial_day", y="session", data=dframe, ax=axes[3][0])
    sns.lineplot(x="trial_day", y="block", data=dframe, ax=axes[4][0])

    fig.savefig(f"{SAVEDIR}/overviewAllTrials.pdf")



    stagelist = set([p["stage"] for p in probedat])
    sesslist = set([p["session"] for p in probedat])    
    kindlist = set([p["kind"] for p in probedat])

    ## PLOT PROBE TASKS OVER THE ENTIRE DAY
    maxtrialsplot = 80

    for kind in kindlist:
        for stage in stagelist:
            for s in sesslist:
                trialsthis = [p["trial"] for p in probedat if p["session"]==s and p["kind"]==kind and p["stage"]==stage]
                fd = FD[s]
                print(f"-- for session {s}, kind {kind}, stage {stage}; trials:")
                print(trialsthis)

                if len(trialsthis)>0:
                    if len(trialsthis)>maxtrialsplot:
                        trialsthis = sorted(random.sample(trialsthis, maxtrialsplot))                        
                        r = None
                    else:
                        r = None
                    titles = []
                    for t in trialsthis:
                        mscore = getTrialsBehEvaluation(fd, t)["output"]["modelscore"]["value"][0][0]
                        bscore = getTrialsBehEvaluation(fd, t)["beh_multiplier"][0][0]                                               
                        titles.append(f"{t},bk{getTrialsBlock(fd, t)},{getTrialsTask(fd, t)['str']}\nmsco{mscore:.2f},bsco{bscore:.2f}")

#                         titles = [f"{t},bk{getTrialsBlock(fd, t)}{getTrialsTask(fd, t)['str']}\nmscore{mscore}" for t in trialsthis]
                    # plot
                    
                    # construct titles
                    
                    fig1 = plotMultTrialsSimple(fd, trialsthis, zoom=True, strokes_ver="peanuts", plot_fix=True,
                                            plotver="strokes", rand_subset = r, titles=titles)

                    scores = [getTrialsScoreRecomputed(fd, t, normalize=True) for t in trialsthis]
                    scores_compos = [getTrialsScoreRecomputed(fd, t, ver="DTW_min", normalize=True) for t in trialsthis]
                    scores_compos2 = [getTrialsScoreRecomputed(fd, t, ver="DTW_min_minus_max", normalize=True) for t in trialsthis]

                    # == plot quick scores
                    fig2 = plt.figure(figsize=(10, 12))

                    plt.subplot(311)
                    plt.title(f"session {s}, kind {kind}, stage {stage}")
                    plt.plot(trialsthis, scores, "ok", label="pts")
    #                 plt.plot(trialsthis, scores_compos, "or", label="compositonal")
    #                 plt.plot(trialsthis, scores_compos2, "og", label="compositonal_min_minus_max")
                    plt.ylabel("score (pts) (norm HD, high is good)")
                    plt.ylim([-0.2, 1])
                    plt.legend()

                    plt.subplot(312)
                    plt.title(f"session {s}, kind {kind}, stage {stage}")
    #                 plt.plot(trialsthis, scores, "ok", label="pts")
                    plt.plot(trialsthis, scores_compos, "or", label="compositonal")
    #                 plt.plot(trialsthis, scores_compos2, "og", label="compositonal_min_minus_max")
                    plt.ylabel("score (compositonal) (norm HD, high is good)")
                    plt.ylim([-0.5, 1])
                    plt.legend()

                    plt.subplot(313)
                    plt.title(f"session {s}, kind {kind}, stage {stage}")
    #                 plt.plot(trialsthis, scores, "ok", label="pts")
    #                 plt.plot(trialsthis, scores_compos, "or", label="compositonal")
                    plt.plot(trialsthis, scores_compos2, "og", label="compositonal_min_minus_max")
                    plt.ylabel("score (compositonal_min_minus_max) (norm HD, high is good)")
                    #     plt.ylim([-0.2, 1])
                    plt.legend()

    #                 plt.subplot(212)
    #                 s1 = (scores - np.mean(scores))/np.std(scores)
    #                 s2 = (scores_compos - np.mean(scores_compos))/np.std(scores_compos)
    #                 s3 = (scores_compos2 - np.mean(scores_compos2))/np.std(scores_compos2)
    #                 plt.plot(trialsthis, s1, "ok", label="pts")
    #                 plt.plot(trialsthis, s2, "or", label="compositonal")
    #                 plt.plot(trialsthis, s3, "og", label="compositonal_min_minus_max")
    #                 plt.title("z-scored")
    #                 plt.ylabel("score (recomputed) (norm HD, high is good)")
    #                 plt.ylim([-3, 3])
    #                 plt.legend()

                    # save
                    fig1.savefig(f"{SAVEDIR}/trialsByProbeKind_{kind}-{stage}-sess{s}-fig1.pdf")
                    fig2.savefig(f"{SAVEDIR}/trialsByProbeKind_{kind}-{stage}-sess{s}-fig2.pdf")
    #                 fig2.savefig(f"{SAVEDIR}/trialsByProbeKind_sess{s}-{kind}-{stage}-fig2.pdf")

# %%
# Learning - same task over time/days

# %%
# Collect all cases where same task is done in different contexts:
# 1) Same animal, diff training
# 2) Diff animal, diff training
# 3) Diff animal, same training (might not be any of this)

# %%
# During 2-stroke, stop after secind stroke?

# Trial end after lift > N seconds? Plot timing distryubitnos./

# %%
# Can decode character?

# %%
# Get more stereotyped with practice 
# seems clear from psychometric tasks

# %%
# CHECK ANALYSES TO DO IN SPREADSHEET

# %%
## ==== PLOT PSYCHOMETRIC PROBES

# %%
# ==== categorize each trial based on its probe type and task id

trials = getIndsTrials(fd)
dat = []
for t in trials:
    if getTrialsFixationSuccess(fd, t):
        probe = getTrialsTaskProbeInfo(fd, t)

        dat.append({
            "filedata":fd,
            "trial":t,
            "unique_task_name":getTrialsUniqueTasknameGood(fd, t),
            "tasknum":probe["tasknum"],
            "task_category":getTrialsTask(fd, t)["stage"],
            "block":getTrialsBlock(fd, t)
        })
from pythonlib.tools.dicttools import printOverviewKeyValues
printOverviewKeyValues(dat);

# %%
CAT1 = None
CAT2 = ["tasknum", []]
plotargs = {"zoom":True, "plotver":"strokes", "markersize":4, "alpha":0.25}

fig = plotTrial2dGrid(datthis, cat1 = CAT1, cat2 = CAT2, ver="beh", plotargs=plotargs);
fig.savefig(f"{SAVEDIR}/psychometric_trials_beh_{settoget}.pdf")
fig = plotTrial2dGrid(datthis, cat1 = CAT1, cat2 = CAT2, ver="task", plotargs=plotargs);
fig.savefig(f"{SAVEDIR}/psychometric_trials_task_{settoget}.pdf")

# %%
# ==== PICK OUT A PARTICULAR PSYCHOMETRIC SET
# THEN PLOT
import copy
for settoget in ["3line_psych1", "3line_psych2", "3line_psych3", 
                 "3line_psych5", "3line_psych6", "3line_psych7"]:
    
    datthis = copy.deepcopy([d for d in dat if d["task_category"]==settoget])
    if len(datthis)==0:
        continue
        
    datthis = sorted(datthis, key=lambda x:x["tasknum"])
    
    # ==== PRINTING INFORMATION
    if True:
        for d in datthis:
            print([d["task_category"], d["tasknum"], d["trial"], d["unique_task_name"]])
        printOverviewKeyValues(datthis);

    ## == reorganize tasknums into rows and cols that allow better visualization of psychometric dimensions
    # probably easiest to handcode
    if settoget=="3line_psych2":
        rowcolmappings = {
            1:{"row":0, "col":0},
            2:{"row":0, "col":1},
            3:{"row":0, "col":2},
            4:{"row":0, "col":3},
            5:{"row":0, "col":4},
            6:{"row":1, "col":0},
            7:{"row":1, "col":1},
            8:{"row":1, "col":2},
            9:{"row":1, "col":3},
            10:{"row":1, "col":4},
            11:{"row":2, "col":0},
            12:{"row":2, "col":1},
            13:{"row":2, "col":2},
            14:{"row":2, "col":3},
            15:{"row":2, "col":4},
            16:{"row":3, "col":2},
            17:{"row":3, "col":0},
            18:{"row":3, "col":1},
            19:{"row":3, "col":3},
            20:{"row":3, "col":4},
        }
    elif settoget=="3line_psych1":
        rowcolmappings = {
            1:{"row":0, "col":0},
            2:{"row":0, "col":1},
            3:{"row":0, "col":2},
            4:{"row":0, "col":3},
            5:{"row":0, "col":4},
            6:{"row":1, "col":0},
            7:{"row":1, "col":1},
            8:{"row":1, "col":2},
            9:{"row":1, "col":3},
            10:{"row":1, "col":4},
            11:{"row":2, "col":0},
            12:{"row":2, "col":1},
            13:{"row":2, "col":2},
            14:{"row":2, "col":3},
            15:{"row":2, "col":4},
        }
    elif settoget=="3line_psych6":
            rowcolmappings = {
            1:{"row":0, "col":0},
            2:{"row":0, "col":1},
            3:{"row":0, "col":2},
            4:{"row":1, "col":0},
            5:{"row":1, "col":1},
            6:{"row":1, "col":2},
            7:{"row":2, "col":0},
            8:{"row":2, "col":1},
            9:{"row":2, "col":2},
            10:{"row":3, "col":0},
            11:{"row":3, "col":2},
        }
    else:
        rowcolmappings = {i+1:{"row":0, "col":i} for i in range(len(set([d["tasknum"] for d in datthis])))}
    # else:
    #     print(settoget)
    #     assert False, "have not coded for this set"

    for d in datthis:
        d["row"]=rowcolmappings[d["tasknum"]]["row"]
        d["col"]=rowcolmappings[d["tasknum"]]["col"]

    CAT1 = ["row", []]
    CAT2 = ["col", []]
    plotargs = {"zoom":True, "plotver":"strokes", "markersize":4, "alpha":0.25}

    fig = plotTrial2dGrid(datthis, cat1 = CAT1, cat2 = CAT2, ver="beh", plotargs=plotargs);
    fig.savefig(f"{SAVEDIR}/psychometric_trials_beh_{settoget}.pdf")
    fig = plotTrial2dGrid(datthis, cat1 = CAT1, cat2 = CAT2, ver="task", plotargs=plotargs);
    fig.savefig(f"{SAVEDIR}/psychometric_trials_task_{settoget}.pdf")

# %%
printOverviewKeyValues(datthis)

# %%
for d in datthis:
    print(d.keys())

# %%
## Quick plot of task categories
import pandas as pd
import seaborn as sns

D = pd.DataFrame(dat)
fig = plt.figure(figsize=(10,35))
sns.scatterplot(x="trial", y="unique_task_name", hue="task_category", data=D)
fig = plt.figure(figsize=(10,35))
sns.scatterplot(x="block", y="unique_task_name", hue="task_category", data=D)

# %%
# OLD PLOTTING 
        DAT, angle_list, category_list, set_list, gdConfigs = \
        getGuideDotSets(fd, trials_list_all, set_variable = set_variable, indcenter = indcenter, 
                       nstrokes=NSTROKES)

        figs = plotTrialsSortedByCategory(DAT, fd, angle_list, set_list, REPLAYNUM = 1, rand_subset = None)
        for i, f in enumerate(figs):
            f.savefig(f"{SAVEDIR}/trialsBehSortedByCategory{i}_nstrokes{NSTROKES}.pdf")

    #     ## Overlay all trials, one plot for each task
    #     Key comparison is the same guide dots, but different task.
    #     Plot, mean across trials, separated by angle and category (imagine a grid).

        for replaynum in [None, 1]:
            for g in gdConfigs:

                anglelist = g["angle"]
                catlist = g["category"]

                for ver in ["beh", "task"]:
                    fig = plotAngleByCatOverlayTrials_(DAT, fd, anglelist, catlist, ver=ver, replaynum=replaynum)
                    fig.savefig(f"{SAVEDIR}/AngleByCatOverlayTrials_{ver}_gconfig{g['id']}_replay{replaynum}_nstrokes{NSTROKES}.pdf")

# %% [markdown]
# ## BELOW - OLD SCRATCH

# %%
# === LOAD ALL SESSIONS FOR A DAY
# A = [("lines1", "Red", 200831),
#  ("lines1", "Pancho", 200831),
#  ("ESC1", "Red", 200830),
#  ("ESC1", "Pancho", 200830)]
A = [("lines2", "Red", 200907),
 ("lines2", "Pancho", 200907)]

for (expt, animal, date) in A:

    # expt = "lines1"
    # animal = "Red"
    # date = 200831

    # expt = "ESC1"
    # animal = "Red"
    # date = 200830

    # simple, just try many sessions...
    fdsessions = []
    FD = {}
    N = 12
    for session in range(10):
        fd = loadSingleData(animal, date, expt, session, resave_as_dict=False, load_resaved_data=True, 
                          resave_overwrite=False)
        if fd is not None:
            print(f"appending fd for sess {session}")
            fdsessions.append({
                "session": session,
                "fd":fd})
            FD[session] = fd
            if session==N-1:
                assert False, "got the end and still found.. you need to search for even more sessions..."

            SAVEDIR = f"{fd['params']['figuredir_notebook']}/probes/{animal}_{date}"
            import os
            os.makedirs(SAVEDIR, exist_ok=True)


    print("--- SUMMARY")
    for f in fdsessions:
        print(f"session: {f['session']}, ntrials: {f['fd']['params']['n_trials']}")


    # === categorize all trials based on task/probe, etc
    probedat = []
    ct = 0
    for sess, fd in FD.items():
        for t in getIndsTrials(fd):
            if getTrialsFixationSuccess(fd, t):
                probe = getTrialsTaskProbeInfo(fd, t)
                task = getTrialsTask(fd, t)
                
#                 print(probe)
                
                if probe["prototype"]==0 and len(probe["saved_setnum"])==0 and probe["resynthesized"]==0:
                    # then this is new random task sampled each block.
                    randomtask = True
                else:
                    randomtask = False

                if probe["probe"]==0:
                    kind = "train"
                else:
                    if probe["feedback_ver"]=="same_as_task" and randomtask==False:
                        if probe["constraints_to_skip"]=={}:
                            kind = "probe1_liketrain"
                        elif "strokes" in probe["constraints_to_skip"].values():
                            kind = "probe1_nostrokeconstraint"
                    elif probe["feedback_ver"]=="same_as_task" and randomtask==True and probe["constraints_to_skip"]=={}:
                        kind = "probe2_liketrain"
                    elif probe["feedback_ver"]=="same_as_task" and randomtask==True and "strokes" in probe["constraints_to_skip"].values():
                        kind = "probe2_nostrokeconstraint"
                    elif probe["feedback_ver"] in ["thresh_active", "mid_reward"] and randomtask==False and "strokes" in probe["constraints_to_skip"].values():
                        kind = "probe3"
                    elif probe["feedback_ver"] in ["same_except_model"] and randomtask==False and "strokes" in probe["constraints_to_skip"].values():
                        kind = "probe3_hdpos"
                    elif probe["feedback_ver"] in ["thresh_active", "mid_reward"] and randomtask==True and "strokes" in probe["constraints_to_skip"].values():
                        kind = "probe4"
                    else:
                        print(probe)
                        assert False, "what kind is this?"

                probedat.append({
                    "session":sess,
                    "trial":t,
                    "trial_day":ct,
                    "kind":kind,
                    "taskname": probe["unique_name"],
                    "stage":task["stage"],
                    "block":getTrialsBlock(FD[sess], t),
                    "prototype":probe["prototype"],
                    "constraints_to_skip":probe["constraints_to_skip"]})
                ct+=1


    # == for each category, list names of all tasks
    kindlist = set([p["kind"] for p in probedat])
    print("probe kinds -- trials");
    for kind in kindlist:
        print(" ")
        print(kind)
        trials = [p["trial"] for p in probedat if p["kind"]==kind]
        tasknames = [p["taskname"] for p in probedat if p["kind"]==kind]
    #     print(trials)
        print(set(tasknames))
        plt.figure()
        plt.plot(trials, tasknames)

    import seaborn as sns
    import pandas as pd
    dframe = pd.DataFrame(probedat)

    # sns.scatterplot(x="trial", y="taskname", data=dframe, hue="kind")
    fig, axes = plt.subplots(5, 1, sharex=True, squeeze=False, figsize=(28, 10))

    sns.scatterplot(x="trial_day", y="kind", data=dframe, hue="kind", ax=axes[0][0])
    sns.scatterplot(x="trial_day", y="stage", data=dframe, hue="kind", ax=axes[1][0])
    sns.scatterplot(x="trial_day", y="stage", data=dframe, hue="prototype", ax=axes[2][0])
    sns.lineplot(x="trial_day", y="session", data=dframe, ax=axes[3][0])
    sns.lineplot(x="trial_day", y="block", data=dframe, ax=axes[4][0])

    fig.savefig(f"{SAVEDIR}/overviewAllTrials.pdf")



    stagelist = set([p["stage"] for p in probedat])
    sesslist = set([p["session"] for p in probedat])    
    kindlist = set([p["kind"] for p in probedat])

    ## PLOT PROBE TASKS OVER THE ENTIRE DAY
    maxtrialsplot = 80

    for kind in kindlist:
        for stage in stagelist:
            for s in sesslist:
                trialsthis = [p["trial"] for p in probedat if p["session"]==s and p["kind"]==kind and p["stage"]==stage]
                fd = FD[s]
                print(f"-- for session {s}, kind {kind}, stage {stage}; trials:")
                print(trialsthis)

                if len(trialsthis)>0:
                    if len(trialsthis)>maxtrialsplot:
                        trialsthis = sorted(random.sample(trialsthis, maxtrialsplot))                        
                        r = None
                    else:
                        r = None
                    titles = []
                    for t in trialsthis:
                        mscore = getTrialsBehEvaluation(fd, t)["output"]["modelscore"]["value"][0][0]
                        bscore = getTrialsBehEvaluation(fd, t)["beh_multiplier"][0][0]                                               
                        titles.append(f"{t},bk{getTrialsBlock(fd, t)},{getTrialsTask(fd, t)['str']}\nmsco{mscore:.2f},bsco{bscore:.2f}")

#                         titles = [f"{t},bk{getTrialsBlock(fd, t)}{getTrialsTask(fd, t)['str']}\nmscore{mscore}" for t in trialsthis]
                    # plot
                    
                    # construct titles
                    
                    fig1 = plotMultTrialsSimple(fd, trialsthis, zoom=True, strokes_ver="peanuts", plot_fix=True,
                                            plotver="strokes", rand_subset = r, titles=titles)

                    scores = [getTrialsScoreRecomputed(fd, t, normalize=True) for t in trialsthis]
                    scores_compos = [getTrialsScoreRecomputed(fd, t, ver="DTW_min", normalize=True) for t in trialsthis]
                    scores_compos2 = [getTrialsScoreRecomputed(fd, t, ver="DTW_min_minus_max", normalize=True) for t in trialsthis]

                    # == plot quick scores
                    fig2 = plt.figure(figsize=(10, 12))

                    plt.subplot(311)
                    plt.title(f"session {s}, kind {kind}, stage {stage}")
                    plt.plot(trialsthis, scores, "ok", label="pts")
    #                 plt.plot(trialsthis, scores_compos, "or", label="compositonal")
    #                 plt.plot(trialsthis, scores_compos2, "og", label="compositonal_min_minus_max")
                    plt.ylabel("score (pts) (norm HD, high is good)")
                    plt.ylim([-0.2, 1])
                    plt.legend()

                    plt.subplot(312)
                    plt.title(f"session {s}, kind {kind}, stage {stage}")
    #                 plt.plot(trialsthis, scores, "ok", label="pts")
                    plt.plot(trialsthis, scores_compos, "or", label="compositonal")
    #                 plt.plot(trialsthis, scores_compos2, "og", label="compositonal_min_minus_max")
                    plt.ylabel("score (compositonal) (norm HD, high is good)")
                    plt.ylim([-0.5, 1])
                    plt.legend()

                    plt.subplot(313)
                    plt.title(f"session {s}, kind {kind}, stage {stage}")
    #                 plt.plot(trialsthis, scores, "ok", label="pts")
    #                 plt.plot(trialsthis, scores_compos, "or", label="compositonal")
                    plt.plot(trialsthis, scores_compos2, "og", label="compositonal_min_minus_max")
                    plt.ylabel("score (compositonal_min_minus_max) (norm HD, high is good)")
                    #     plt.ylim([-0.2, 1])
                    plt.legend()

    #                 plt.subplot(212)
    #                 s1 = (scores - np.mean(scores))/np.std(scores)
    #                 s2 = (scores_compos - np.mean(scores_compos))/np.std(scores_compos)
    #                 s3 = (scores_compos2 - np.mean(scores_compos2))/np.std(scores_compos2)
    #                 plt.plot(trialsthis, s1, "ok", label="pts")
    #                 plt.plot(trialsthis, s2, "or", label="compositonal")
    #                 plt.plot(trialsthis, s3, "og", label="compositonal_min_minus_max")
    #                 plt.title("z-scored")
    #                 plt.ylabel("score (recomputed) (norm HD, high is good)")
    #                 plt.ylim([-3, 3])
    #                 plt.legend()

                    # save
                    fig1.savefig(f"{SAVEDIR}/trialsByProbeKind_{kind}-{stage}-sess{s}-fig1.pdf")
                    fig2.savefig(f"{SAVEDIR}/trialsByProbeKind_{kind}-{stage}-sess{s}-fig2.pdf")
    #                 fig2.savefig(f"{SAVEDIR}/trialsByProbeKind_sess{s}-{kind}-{stage}-fig2.pdf")

# %%
getTrialsTask(fd, t)["savedTaskSet"]

# %%
expt = "lines2"
animal = "Pancho"
date = 200904

fdsessions = []
FD = {}
N = 12
for session in range(10):
    fd = loadSingleData(animal, date, expt, session, resave_as_dict=False, load_resaved_data=True, 
                      resave_overwrite=False)
    if fd is not None:
        print(f"appending fd for sess {session}")
        fdsessions.append({
            "session": session,
            "fd":fd})
        FD[session] = fd
        if session==N-1:
            assert False, "got the end and still found.. you need to search for even more sessions..."

        SAVEDIR = f"{fd['params']['figuredir_notebook']}/probes/{animal}_{date}"
        import os
        os.makedirs(SAVEDIR, exist_ok=True)


print("--- SUMMARY")
for f in fdsessions:
    print(f"session: {f['session']}, ntrials: {f['fd']['params']['n_trials']}")


# === categorize all trials based on task/probe, etc
probedat = []
ct = 0
for sess, fd in FD.items():
    for t in getIndsTrials(fd):
        if getTrialsFixationSuccess(fd, t):
            probe = getTrialsTaskProbeInfo(fd, t)
            task = getTrialsTask(fd, t)

            if probe["probe"]==0:
                kind = "train"
            else:
                if probe["feedback_ver"]=="same_as_task" and probe["prototype"]==1:
                    if probe["constraints_to_skip"]=={}:
                        kind = "probe1_liketrain"
                    elif "strokes" in probe["constraints_to_skip"].values():
                        kind = "probe1_nostrokeconstraint"
                elif probe["feedback_ver"]=="same_as_task" and probe["prototype"]==0 and probe["constraints_to_skip"]=={}:
                    kind = "probe2_liketrain"
                elif probe["feedback_ver"]=="same_as_task" and probe["prototype"]==0 and "strokes" in probe["constraints_to_skip"].values():
                    kind = "probe2_nostrokeconstraint"
                elif probe["feedback_ver"] in ["thresh_active", "mid_reward"] and probe["prototype"]==1 and "strokes" in probe["constraints_to_skip"].values():
                    kind = "probe3"
                elif probe["feedback_ver"] in ["same_except_model"] and probe["prototype"]==1 and "strokes" in probe["constraints_to_skip"].values():
                    kind = "probe3_hdpos"
                elif probe["feedback_ver"] in ["thresh_active", "mid_reward"] and probe["prototype"]==0 and "strokes" in probe["constraints_to_skip"].values():
                    kind = "probe4"
                else:
                    print(probe)
                    assert False, "what kind is this?"

            probedat.append({
                "session":sess,
                "trial":t,
                "trial_day":ct,
                "kind":kind,
                "taskname": probe["unique_name"],
                "stage":task["stage"],
                "prototype":probe["prototype"],
                "constraints_to_skip":probe["constraints_to_skip"]})
            ct+=1

# %%
## for each trial also get online and offline score
for p in probedat:
    s = p["session"]
    t = p["trial"]
    
    p["bk"] = getTrialsBlock(FD[s], t)
    p["bq"] = getTrialsBloque(FD[s], t)
    
    # score
    if getTrialsFixationSuccess(FD[s], t):
        p["score_model"] = getTrialsOutcomesWrapper(FD[s], t)["beh_evaluation"]["output"]["modelscore"]["value"][0][0]
        p["score_hd"] = getTrialsOutcomesWrapper(FD[s], t)["beh_evaluation"]["output"]["hausdorff"]["value"][0][0]
        p["score_offline"] = getTrialsScoreRecomputed(FD[s], t)
    
    
    
    

import pandas as pd

dfthis = pd.DataFrame(probedat)
dfthis

# %%
### import seaborn as sns

y = "score_model"
sns.relplot(x = "trial", y=y, hue="bk", data=dfthis, row="kind", kind="scatter", aspect=3)
sns.relplot(x = "trial_day", y=y, hue="bk", data=dfthis, row="kind", kind="scatter", aspect=3)
sns.relplot(x = "bq", y=y, hue="bk", data=dfthis, row="kind", kind="scatter", aspect=3)

# %%
### import seaborn as sns

y = "score_model"
sns.catplot(x = "bk", y=y, data=dfthis, row="kind", kind="point", aspect=3)
# sns.catplot(x = "bq", y=y, data=dfthis, col="kind", row="bk", kind="point", aspect=3)
sns.catplot(x = "bq", y=y, data=dfthis, row="kind", hue="bk", kind="point", aspect=3)

# %%
## COMPUTE COMPOSITIONAL SCORE
# [Quick version] DTW score relative to non-DTW score

## ==== [testing] stroke based hd
from pythonlib.tools.stroketools import distanceDTW
t = random.sample(getIndsTrials(fd),1)[0]

strokes_beh = getTrialsStrokesByPeanuts(fd, t, replaynum=1)
strokes_task = getTrialsTaskAsStrokes(fd, t)

for ass in [True, False]:
    print(f"assymetric: {ass}")
    plotTrialSimple(fd, t, zoom=True, plot_fix=False, plotver="strokes", 
                    use_peanut_params={'replaynum': 1, 'active': True})

    print(distanceDTW(strokes_beh, strokes_task[::-1], ver="segments", asymmetric=ass))
    print(distanceDTW(strokes_beh, strokes_task, ver="segments", asymmetric=ass))

    plt.figure(figsize=(10,10))
    ax = plt.subplot(211)
    plotDatStrokes(strokes_beh, ax=ax)
    plotDatStrokes(strokes_task[::-1], ax=ax)

    ax = plt.subplot(212)
    plotDatStrokes(strokes_beh, ax=ax)
    plotDatStrokes(strokes_task, ax=ax)

# compute minimum score for all permutations of task strokes
# make assymetric false, so forced to use all task strokes.
print("-- all permutations")
from itertools import permutations
scores =[]
for s in permutations(strokes_task):
    print(distanceDTW(strokes_beh, s, ver="segments", asymmetric=False))
    scores.append(distanceDTW(strokes_beh, s, ver="segments", asymmetric=False)[0])
score = min(scores)
print(score)

# %%
from pythonlib.tools.listtools import permuteRand

permuteRand([1,2,3], 6, not_enough_ok=True)
from itertools import permutations

for i in permutations([1,2,3]):
    print(i)

# %% [markdown]
# ## SCRATCH

# %%
featurestoplot = []
for key, val in getTrialsBlockParams(fd, 1)["behEval"]["beh_eval"].items():
    if val["feature"] =="hausdorff" and val["weight"][0][0]>0:
        featurestoplot.append("hausdorff")
    if val["feature"] =="frac_touched" and val["weight"][0][0]>0:
        featurestoplot.append("frac_touched")
featurestoplot.append("score_offline")

fig1, fig2 = plotOverview_(df, featurestoplot=featurestoplot)
fig1.savefig(f"{SAVEDIRDAY}/overview1.pdf")
fig2.savefig(f"{SAVEDIRDAY}/overview2.pdf")

# 2) relationship between reward and factors that go into reward
figs = plotReward(df, featurestoplot=featurestoplot)
for i, f in enumerate(figs):
    f.savefig(f"{SAVEDIRDAY}/reward_score_{i}.pdf")

# 3) PLOT BEHAVIOR FOR TRIALS SORTED BY SCORE
import copy
scoretypes = copy.copy(featurestoplot)
scoretypes.extend(["behscore", "reward"])
for score_type in scoretypes:
    FIGS = plotBehSortedByScore(df, fd, score_type)
    for ver, figs in FIGS.items():
        for i, f in enumerate(figs):
            f.savefig(f"{SAVEDIRDAY}/trialsSortedByScore_{score_type}_{ver}_{i}_.pdf")

# 4) Plot behavior subsampling in chronological order
trials = [t for t in getIndsTrials(fd) if getTrialsFixationSuccess(fd, t)]
Nrand = 80
fig = plotMultTrialsSimple(fd, trials, zoom=True, strokes_ver="peanuts", plot_fix=False,
                        plotver="strokes", rand_subset=Nrand)
fig.savefig(f"{SAVEDIRDAY}/trialsRandomChronOrder.pdf")

# 5) TASK VISUALIZATIONS, SCHEDULE, REPETITION
figs = plotTaskSchedules(df)
for i, f in enumerate(figs):
    f.savefig(f"{SAVEDIRDAY}/taskSchedule{i}.pdf")

# %%
if False:
    animal = "Pancho"
    expt = "pilot"
    date = 200822
    session = 1

    fd = loadSingleData(animal, date, expt, session, resave_as_dict=False, load_resaved_data=True, 
                              resave_overwrite=False)

    ## ==== [testing] stroke based hd
    from pythonlib.tools.stroketools import distanceDTW
    t = random.sample(getIndsTrials(fd),1)[0]

    for ass in [True, False]:
        print(f"assymetric: {ass}")
        plotTrialSimple(fd, t, zoom=True, plot_fix=False, plotver="strokes", 
                        use_peanut_params={'replaynum': 1, 'active': True})

        strokes_beh = getTrialsStrokesByPeanuts(fd, t, replaynum=1)
        strokes_task = getTrialsTaskAsStrokes(fd, t)
        print(distanceDTW(strokes_beh, strokes_task[::-1], ver="segments", asymmetric=ass))
        print(distanceDTW(strokes_beh, strokes_task, ver="segments", asymmetric=ass))

        plt.figure(figsize=(10,10))
        ax = plt.subplot(211)
        plotDatStrokes(strokes_beh, ax=ax)
        plotDatStrokes(strokes_task[::-1], ax=ax)

        ax = plt.subplot(212)
        plotDatStrokes(strokes_beh, ax=ax)
        plotDatStrokes(strokes_task, ax=ax)

# %%
## ==== plot scoring separated by task type

df = extractSessionDf(fd)

# === add note about what probe type this is

# %% [markdown]
# ## TO DO:
# (1) get all permutations
# (2) normalize by num strokes.
# (3) systematic - compare to old version.
