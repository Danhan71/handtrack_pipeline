# %%
""" 
Looking at Otis touch data. confirming that indeed is aborting when multitouch, 
I am suspiciuos someting is wierd to allow him to get away with multitouch/
CONCLUSION:
Looks fine. he seems to be really good at claw.
Also confirmed that whenever there is 2nd touch,t here is also af irst touch. i.e.
not jumping back and forth.
"""

# %%
# %load_ext autoreload
# %autoreload 2

# %cd ..


from tools.utils import * 
from tools.plots import *
from tools.analy import *
from tools.calc import *
from tools.analyplot import *
from pythonlib.drawmodel.analysis import *
from pythonlib.tools.stroketools import *
# Out:
# /data1/code/python/drawmonkey
# NOTE: need to not overwrite strokes_all_task, because then the orders saved will stop being accurate. Modify

# %%
animal = "Otis"
date = 200817
expt = "pilot"
session = 1

from tools.preprocess import *
fd = loadSingleData(animal, date, expt, session, resave_as_dict=False, load_resaved_data=True, 
                      resave_overwrite=False)
# Out:
# found one matching filename: ['/data2/animals/Otis/200817/200817_110034_pilot_Otis_1.h5']
# found one matching filename: ['/data2/animals/Otis/200817/200817_110034_pilot_Otis_1.pkl']
# -- loaded presaved data: /data2/animals/Otis/200817/200817_110034_pilot_Otis_1.pkl

# %%
## PLOTTING EACH TRIAL WHERE THERE IS MULTITOUCH

X = np.array(fd["trials"][20]["AnalogData"]["Touch"])

plt.figure(figsize=(12,20))
Y = ~np.isnan(X)

for i, y in enumerate(Y):
    plt.subplot(4,1,i+1)
    plt.plot(y, '-')


for t in getIndsTrials(fd):
    X = np.array(fd["trials"][t]["AnalogData"]["Touch"])
    if np.any(~np.isnan(X[2,1200:])) | np.any(~np.isnan(X[3,1200:])):
        plt.figure(figsize=(12,20))
        Y = ~np.isnan(X)

        for i, y in enumerate(Y):
            plt.subplot(4,1,i+1)
            plt.plot(y, '-')
            plt.title(t)
        print(t)
#         assert False
# Out:
# got 985 total trials
# 3
# 5
# 7
# 17
# 36
# 47
# 76
# 77
# 80
# 81
# 86
# 87
# 88
# 89
# 144
# 165
# 175
# 182
# 187
# 193
# /home/lucast4/miniconda3/envs/drag/lib/python3.7/site-packages/ipykernel_launcher.py:16: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   app.launch_new_instance()
# 197
# 212
# 345
# 347
# 349
# 350
# 353
# 356
# 360
# 450
# 451
# 462
# 463
# 467
# 468
# 470
# 471
# 477
# 480
# 494
# 498
# 508
# 509
# 510
# 520
# 522
# 527
# 756
# 757
# 760
# 761
# 765
# 769
# 770
# 777
# 792
# 805
# 827
# 870
# 922
# 923
