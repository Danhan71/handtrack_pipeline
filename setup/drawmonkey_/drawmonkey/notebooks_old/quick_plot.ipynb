# %%
"""OLDEST - """


# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
fname = []
fname[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-695-75be1f4c54b6> in <module>
#       1 fname = []
# ----> 2 fname[0]
#
# IndexError: list index out of range

# %%
# %%time
from tools.preprocess import *
# filedata = loadSingleData("Pancho", 200226, "pilot", 4, resave_as_dict=False, load_resaved_data=True)
# filedata = loadSingleData("Pancho", 200226, "pilot", 4, resave_as_dict=False, load_resaved_data=False)
filedata = loadSingleData("Pancho", 200226, "pilot", 1, resave_as_dict=False, load_resaved_data=True, 
                      resave_overwrite=False)
# Out:
# found one matching filename: ['/data2/animals/Pancho/200226/200226_121930_pilot_Pancho_1.h5']
# found one matching filename: ['/data2/animals/Pancho/200226/200226_121930_pilot_Pancho_1.pkl']
# CPU times: user 285 ms, sys: 24.4 ms, total: 309 ms
# Wall time: 308 ms

# %%
## plot/display things for a single trial
from tools.plots import plotTrialSingleOverview
import random

if True:
    n_trials = filedata["params"]["n_trials"]
    t = random.randint(0, n_trials)
    # t = 198
    print(f"this trial {t}")
    plotTrialSingleOverview(filedata, t)
else:
    n_trials = filedata2["params"]["n_trials"]
    t = random.randint(0, n_trials)
    # t = 198
    print(f"this trial {t}")
    plotTrialSingleOverview(filedata2, t)
# Out:
# this trial 6

# %%
t=84

print(f"this trial {t}")
plotTrialSingleOverview(filedata2, t)
# Out:
# this trial 84

# %%
## TO DO:
# plot more trials
# plot timecourses, aligned at go cue
# do analyses (e.g, aligning by first stroke)

# summary plot (accuracy, failure rates, timing, etc)

# %%
from tools.utils import getTrialsPeanutPos
# Out:
# ERROR - allPeanutPos is not aligned with data truials
# Not returning peanut positions - should fix this problem
# fix by noting that skips whenever peanutpos is empty

# %% [raw]
# ################ TODO
# # load video as well
# # segment into strokes
# # overlay reward
# # plot params for this trial

# %%
event = "start"
dat_behcodes_num == [key for key in beh_codes.keys() if beh_codes[key]==event][0]

# %%
errorcode = data[f"Trial{t}"]["TrialError"][()][0]

# %%
fracinkgotten_[0]

# %%
trialoutcomes

# %%
from tools.utils import getTrialsTimeOfBehCode

time_go = getTrialsTimeOfBehCode(filedata, t, "go (draw)")

inds = dat_t > time_go
t_this = dat_t[inds]
x_this = dat_touch_x[inds]
y_this = dat_touch_y[inds]

plt.plot(x_this, y_this, '-ok')

# %%
[key for key in beh_codes.keys() if beh_codes[key]==event]

# %%
task = TrialRecord["User"]["CurrentTask"][f"{t}"][""]

# %%
import matplotlib.gridspec as gridspec
fig = plt.figure(1)
# set up subplot grid
gridspec.GridSpec(3,3)

# large subplot
plt.subplot2grid((3,3), (0,0), colspan=2, rowspan=3)
plt.title('asdfa')

plt.subplot2grid((3,3), (0,2), colspan=1, rowspan=1)
plt.title('dasdfasfsdf')

# %%
dir(a0)

# %%
trial_outcomes_key = TrialRecord["User"]["TrialOutcomes"][t]

# print(trial_outcomes_key)

# %%
TrialRecord["User"]["TrialOutcomes"]["Key"]["1"].value.decode()

# %%
for t in range(200, 250):
    try:
        print(TrialRecord["User"]["TrialOutcomes"]["Value"][f"{t}"].value.decode())
    except:
        print(TrialRecord["User"]["TrialOutcomes"]["Value"][f"{t}"].value)

# %%
        
# print_level(TrialRecord)

trial_zero=0
TrialRecord["ConditionsPlayed"][trial_zero]
TrialRecord["BlocksPlayed"][trial_zero]
TrialRecord["TrialErrors"][trial_zero]
TrialRecord["ReactionTimes"][trial_zero]
assert TrialRecord["SimulationMode"][:]==0


TrialRecord["User"]["Params"][trial_zero]
TrialRecord["User"]["CurrentTask"][trial_zero]
TrialRecord["User"]["InkGotten"][trial_zero]
TrialRecord["User"]["InkPositions"][trial_zero]
TrialRecord["User"]["Params"][trial_zero]
TrialRecord["User"]["Params"][trial_zero]

print_level(TrialRecord["User"])

# %%
trial_one = trial_zero+1

print_level(TrialRecord["User"]["CurrentTask"][str(trial_one)])





# TrialRecord["User"]["InkPositions"][trial_zero]

# %%
TrialRecord["User"]["CurrentTask"][str(trial_one)]["str"].value.decode()

# %%
TrialRecord["User"]["CurrentTask"][str(trial_one)]["x"].value

# %%
Trial1/AnalogData/Touch
Trial1/BehavioralCodes

# %%
data["Trial1"]["AnalogData"]["Webcam1"]["Time"][:][0]
print(data["Trial1"]["AnalogData"]["Webcam1"]["Filename"])

# %%
for key in TrialRecord.keys():
    list(TrialRecord["User"].keys())

NTRIALS = len(TrialRecord["User"]["InkPositions"])
PIX_PER_DEG = 26.646;
PIX_PER_UNIT = (1024, 768)

# For each trial make a plot
for i in range(NTRIALS):
    ii = i+1;
    datthis = data[f"Trial{ii}"]

    errorcode = datthis["TrialError"][:]
    touchdat = datthis["AnalogData"]["Touch"][:]
    x = touchdat[0]
    y = touchdat[1]
    
    dat = dat*PIX_PER_DEG






# NTRIALS = len
