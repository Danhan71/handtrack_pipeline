# %%
""" goal: go thru all specified days to find task blocks that fit the desired criteria
also finds the tasks that fit criteria.
potnetially pulls all out for a global analysis.

"""
# Out:
# ' goal: analysis of kineamtics of trials.\nmethod of making a summary heat map showing (1) direction bias and (2) frequency of 1st, 2nd touch..\n\n'

# %%
# %load_ext autoreload
# %autoreload 2

from tools.utils import * 
from tools.plots import *
from tools.analy import *
from tools.calc import *
from tools.analyplot import *
# Out:
# NOTE: need to not overwrite strokes_all_task, because then the orders saved will stop being accurate. Modify

# %%
# === go over days.
from pythonlib.tools.expttools import getDateList
from tools.preprocess import loadSingleData

dates = getDateList(200223, 200227)
animal = "Pancho"
expt = "pilot"
sessions = range(20)

outdict = []
for d in dates:
    for s in sessions:
        # === 1) load filedata
        filedata = loadSingleData(animal, d, expt, s, resave_as_dict=False, load_resaved_data=True, 
                              resave_overwrite=False)
        
        if not filedata is None:
            
            blocks = [getTrialsBlockParams(filedata, t) for t in getIndsTrials(filedata)]
            outdict.append({
                "date":d,
                "sess":s,
                "expt":expt,
                "animal":animal,
                "behtype_trials":[b["behtype"]["type"] for b in blocks],
                "EDGE_FIRST_trials":[b["params_task"]["EDGE_FIRST"] for b in blocks if "EDGE_FIRST" in b.keys()],
                "inkrate_time_trials":[b["params_task"]["inkrate_time"] for b in blocks],
                "taskstages":getMultTrialsTaskStages(filedata),
            })
# Out:
# did not find any glob match to /data2/animals/Pancho/200223/200223_*_pilot_Pancho_0.h5!!
# - No h5 file for Pancho, 200223, pilot, 0 - returning None!
# found one matching filename: ['/data2/animals/Pancho/200223/200223_141430_pilot_Pancho_1.h5']
# found one matching filename: ['/data2/animals/Pancho/200223/200223_141430_pilot_Pancho_1.pkl']
# -- loaded presaved data: /data2/animals/Pancho/200223/200223_141430_pilot_Pancho_1.pkl
# got 238 total trials
# got 238 total trials
# found one matching filename: ['/data2/animals/Pancho/200223/200223_144535_pilot_Pancho_2.h5']
# found one matching filename: ['/data2/animals/Pancho/200223/200223_144535_pilot_Pancho_2.pkl']
# -- loaded presaved data: /data2/animals/Pancho/200223/200223_144535_pilot_Pancho_2.pkl
# got 375 total trials
# got 375 total trials
# found one matching filename: ['/data2/animals/Pancho/200223/200223_152953_pilot_Pancho_3.h5']
# found one matching filename: ['/data2/animals/Pancho/200223/200223_152953_pilot_Pancho_3.pkl']
# -- loaded presaved data: /data2/animals/Pancho/200223/200223_152953_pilot_Pancho_3.pkl
# got 363 total trials
# got 363 total trials
# did not find any glob match to /data2/animals/Pancho/200223/200223_*_pilot_Pancho_4.h5!!
# - No h5 file for Pancho, 200223, pilot, 4 - returning None!
# did not find any glob match to /data2/animals/Pancho/200223/200223_*_pilot_Pancho_5.h5!!
# - No h5 file for Pancho, 200223, pilot, 5 - returning None!
# did not find any glob match to /data2/animals/Pancho/200223/200223_*_pilot_Pancho_6.h5!!
# - No h5 file for Pancho, 200223, pilot, 6 - returning None!
# did not find any glob match to /data2/animals/Pancho/200223/200223_*_pilot_Pancho_7.h5!!
# - No h5 file for Pancho, 200223, pilot, 7 - returning None!
# did not find any glob match to /data2/animals/Pancho/200223/200223_*_pilot_Pancho_8.h5!!
# - No h5 file for Pancho, 200223, pilot, 8 - returning None!
# did not find any glob match to /data2/animals/Pancho/200223/200223_*_pilot_Pancho_9.h5!!
# - No h5 file for Pancho, 200223, pilot, 9 - returning None!
# did not find any glob match to /data2/animals/Pancho/200223/200223_*_pilot_Pancho_10.h5!!
# - No h5 file for Pancho, 200223, pilot, 10 - returning None!
# did not find any glob match to /data2/animals/Pancho/200223/200223_*_pilot_Pancho_11.h5!!
# - No h5 file for Pancho, 200223, pilot, 11 - returning None!
# did not find any glob match to /data2/animals/Pancho/200223/200223_*_pilot_Pancho_12.h5!!
# - No h5 file for Pancho, 200223, pilot, 12 - returning None!
# did not find any glob match to /data2/animals/Pancho/200223/200223_*_pilot_Pancho_13.h5!!
# - No h5 file for Pancho, 200223, pilot, 13 - returning None!
# did not find any glob match to /data2/animals/Pancho/200223/200223_*_pilot_Pancho_14.h5!!
# - No h5 file for Pancho, 200223, pilot, 14 - returning None!
# did not find any glob match to /data2/animals/Pancho/200223/200223_*_pilot_Pancho_15.h5!!
# - No h5 file for Pancho, 200223, pilot, 15 - returning None!
# did not find any glob match to /data2/animals/Pancho/200223/200223_*_pilot_Pancho_16.h5!!
# - No h5 file for Pancho, 200223, pilot, 16 - returning None!
# did not find any glob match to /data2/animals/Pancho/200223/200223_*_pilot_Pancho_17.h5!!
# - No h5 file for Pancho, 200223, pilot, 17 - returning None!
# did not find any glob match to /data2/animals/Pancho/200223/200223_*_pilot_Pancho_18.h5!!
# - No h5 file for Pancho, 200223, pilot, 18 - returning None!
# did not find any glob match to /data2/animals/Pancho/200223/200223_*_pilot_Pancho_19.h5!!
# - No h5 file for Pancho, 200223, pilot, 19 - returning None!
# did not find any glob match to /data2/animals/Pancho/200224/200224_*_pilot_Pancho_0.h5!!
# - No h5 file for Pancho, 200224, pilot, 0 - returning None!
# found one matching filename: ['/data2/animals/Pancho/200224/200224_131050_pilot_Pancho_1.h5']
# found one matching filename: ['/data2/animals/Pancho/200224/200224_131050_pilot_Pancho_1.pkl']
# -- loaded presaved data: /data2/animals/Pancho/200224/200224_131050_pilot_Pancho_1.pkl
# got 279 total trials
# got 279 total trials
# found one matching filename: ['/data2/animals/Pancho/200224/200224_134352_pilot_Pancho_2.h5']
# found one matching filename: ['/data2/animals/Pancho/200224/200224_134352_pilot_Pancho_2.pkl']
# -- loaded presaved data: /data2/animals/Pancho/200224/200224_134352_pilot_Pancho_2.pkl
# got 169 total trials
# got 169 total trials
# found one matching filename: ['/data2/animals/Pancho/200224/200224_140534_pilot_Pancho_3.h5']
# found one matching filename: ['/data2/animals/Pancho/200224/200224_140534_pilot_Pancho_3.pkl']
# -- loaded presaved data: /data2/animals/Pancho/200224/200224_140534_pilot_Pancho_3.pkl
# got 864 total trials
# got 864 total trials
# did not find any glob match to /data2/animals/Pancho/200224/200224_*_pilot_Pancho_4.h5!!
# - No h5 file for Pancho, 200224, pilot, 4 - returning None!
# did not find any glob match to /data2/animals/Pancho/200224/200224_*_pilot_Pancho_5.h5!!
# - No h5 file for Pancho, 200224, pilot, 5 - returning None!
# did not find any glob match to /data2/animals/Pancho/200224/200224_*_pilot_Pancho_6.h5!!
# - No h5 file for Pancho, 200224, pilot, 6 - returning None!
# did not find any glob match to /data2/animals/Pancho/200224/200224_*_pilot_Pancho_7.h5!!
# - No h5 file for Pancho, 200224, pilot, 7 - returning None!
# did not find any glob match to /data2/animals/Pancho/200224/200224_*_pilot_Pancho_8.h5!!
# - No h5 file for Pancho, 200224, pilot, 8 - returning None!
# did not find any glob match to /data2/animals/Pancho/200224/200224_*_pilot_Pancho_9.h5!!
# - No h5 file for Pancho, 200224, pilot, 9 - returning None!
# did not find any glob match to /data2/animals/Pancho/200224/200224_*_pilot_Pancho_10.h5!!
# - No h5 file for Pancho, 200224, pilot, 10 - returning None!
# did not find any glob match to /data2/animals/Pancho/200224/200224_*_pilot_Pancho_11.h5!!
# - No h5 file for Pancho, 200224, pilot, 11 - returning None!
# did not find any glob match to /data2/animals/Pancho/200224/200224_*_pilot_Pancho_12.h5!!
# - No h5 file for Pancho, 200224, pilot, 12 - returning None!
# did not find any glob match to /data2/animals/Pancho/200224/200224_*_pilot_Pancho_13.h5!!
# - No h5 file for Pancho, 200224, pilot, 13 - returning None!
# did not find any glob match to /data2/animals/Pancho/200224/200224_*_pilot_Pancho_14.h5!!
# - No h5 file for Pancho, 200224, pilot, 14 - returning None!
# did not find any glob match to /data2/animals/Pancho/200224/200224_*_pilot_Pancho_15.h5!!
# - No h5 file for Pancho, 200224, pilot, 15 - returning None!
# did not find any glob match to /data2/animals/Pancho/200224/200224_*_pilot_Pancho_16.h5!!
# - No h5 file for Pancho, 200224, pilot, 16 - returning None!
# did not find any glob match to /data2/animals/Pancho/200224/200224_*_pilot_Pancho_17.h5!!
# - No h5 file for Pancho, 200224, pilot, 17 - returning None!
# did not find any glob match to /data2/animals/Pancho/200224/200224_*_pilot_Pancho_18.h5!!
# - No h5 file for Pancho, 200224, pilot, 18 - returning None!
# did not find any glob match to /data2/animals/Pancho/200224/200224_*_pilot_Pancho_19.h5!!
# - No h5 file for Pancho, 200224, pilot, 19 - returning None!
# did not find any glob match to /data2/animals/Pancho/200225/200225_*_pilot_Pancho_0.h5!!
# - No h5 file for Pancho, 200225, pilot, 0 - returning None!
# found one matching filename: ['/data2/animals/Pancho/200225/200225_160053_pilot_Pancho_1.h5']
# found one matching filename: ['/data2/animals/Pancho/200225/200225_160053_pilot_Pancho_1.pkl']
# -- loaded presaved data: /data2/animals/Pancho/200225/200225_160053_pilot_Pancho_1.pkl
# got 35 total trials
# got 35 total trials
# found one matching filename: ['/data2/animals/Pancho/200225/200225_160614_pilot_Pancho_2.h5']
# found one matching filename: ['/data2/animals/Pancho/200225/200225_160614_pilot_Pancho_2.pkl']
# -- loaded presaved data: /data2/animals/Pancho/200225/200225_160614_pilot_Pancho_2.pkl
# got 580 total trials
# got 580 total trials
# found one matching filename: ['/data2/animals/Pancho/200225/200225_170944_pilot_Pancho_3.h5']
# found one matching filename: ['/data2/animals/Pancho/200225/200225_170944_pilot_Pancho_3.pkl']
# -- loaded presaved data: /data2/animals/Pancho/200225/200225_170944_pilot_Pancho_3.pkl
# got 287 total trials
# got 287 total trials
# did not find any glob match to /data2/animals/Pancho/200225/200225_*_pilot_Pancho_4.h5!!
# - No h5 file for Pancho, 200225, pilot, 4 - returning None!
# did not find any glob match to /data2/animals/Pancho/200225/200225_*_pilot_Pancho_5.h5!!
# - No h5 file for Pancho, 200225, pilot, 5 - returning None!
# did not find any glob match to /data2/animals/Pancho/200225/200225_*_pilot_Pancho_6.h5!!
# - No h5 file for Pancho, 200225, pilot, 6 - returning None!
# did not find any glob match to /data2/animals/Pancho/200225/200225_*_pilot_Pancho_7.h5!!
# - No h5 file for Pancho, 200225, pilot, 7 - returning None!
# did not find any glob match to /data2/animals/Pancho/200225/200225_*_pilot_Pancho_8.h5!!
# - No h5 file for Pancho, 200225, pilot, 8 - returning None!
# did not find any glob match to /data2/animals/Pancho/200225/200225_*_pilot_Pancho_9.h5!!
# - No h5 file for Pancho, 200225, pilot, 9 - returning None!
# did not find any glob match to /data2/animals/Pancho/200225/200225_*_pilot_Pancho_10.h5!!
# - No h5 file for Pancho, 200225, pilot, 10 - returning None!
# did not find any glob match to /data2/animals/Pancho/200225/200225_*_pilot_Pancho_11.h5!!
# - No h5 file for Pancho, 200225, pilot, 11 - returning None!
# did not find any glob match to /data2/animals/Pancho/200225/200225_*_pilot_Pancho_12.h5!!
# - No h5 file for Pancho, 200225, pilot, 12 - returning None!
# did not find any glob match to /data2/animals/Pancho/200225/200225_*_pilot_Pancho_13.h5!!
# - No h5 file for Pancho, 200225, pilot, 13 - returning None!
# did not find any glob match to /data2/animals/Pancho/200225/200225_*_pilot_Pancho_14.h5!!
# - No h5 file for Pancho, 200225, pilot, 14 - returning None!
# did not find any glob match to /data2/animals/Pancho/200225/200225_*_pilot_Pancho_15.h5!!
# - No h5 file for Pancho, 200225, pilot, 15 - returning None!
# did not find any glob match to /data2/animals/Pancho/200225/200225_*_pilot_Pancho_16.h5!!
# - No h5 file for Pancho, 200225, pilot, 16 - returning None!
# did not find any glob match to /data2/animals/Pancho/200225/200225_*_pilot_Pancho_17.h5!!
# - No h5 file for Pancho, 200225, pilot, 17 - returning None!
# did not find any glob match to /data2/animals/Pancho/200225/200225_*_pilot_Pancho_18.h5!!
# - No h5 file for Pancho, 200225, pilot, 18 - returning None!
# did not find any glob match to /data2/animals/Pancho/200225/200225_*_pilot_Pancho_19.h5!!
# - No h5 file for Pancho, 200225, pilot, 19 - returning None!
# did not find any glob match to /data2/animals/Pancho/200226/200226_*_pilot_Pancho_0.h5!!
# - No h5 file for Pancho, 200226, pilot, 0 - returning None!
# found one matching filename: ['/data2/animals/Pancho/200226/200226_121930_pilot_Pancho_1.h5']
# found one matching filename: ['/data2/animals/Pancho/200226/200226_121930_pilot_Pancho_1.pkl']
# -- loaded presaved data: /data2/animals/Pancho/200226/200226_121930_pilot_Pancho_1.pkl
# got 617 total trials
# got 617 total trials
# found one matching filename: ['/data2/animals/Pancho/200226/200226_134021_pilot_Pancho_2.h5']
# found one matching filename: ['/data2/animals/Pancho/200226/200226_134021_pilot_Pancho_2.pkl']
# -- loaded presaved data: /data2/animals/Pancho/200226/200226_134021_pilot_Pancho_2.pkl
# got 461 total trials
# got 461 total trials
# found one matching filename: ['/data2/animals/Pancho/200226/200226_144919_pilot_Pancho_3.h5']
# found one matching filename: ['/data2/animals/Pancho/200226/200226_144919_pilot_Pancho_3.pkl']
# -- loaded presaved data: /data2/animals/Pancho/200226/200226_144919_pilot_Pancho_3.pkl
# got 254 total trials
# got 254 total trials
# found one matching filename: ['/data2/animals/Pancho/200226/200226_153349_pilot_Pancho_4.h5']
# found one matching filename: ['/data2/animals/Pancho/200226/200226_153349_pilot_Pancho_4.pkl']
# -- loaded presaved data: /data2/animals/Pancho/200226/200226_153349_pilot_Pancho_4.pkl
# got 12 total trials
# got 12 total trials
# found one matching filename: ['/data2/animals/Pancho/200226/200226_153642_pilot_Pancho_5.h5']
# found one matching filename: ['/data2/animals/Pancho/200226/200226_153642_pilot_Pancho_5.pkl']
# -- loaded presaved data: /data2/animals/Pancho/200226/200226_153642_pilot_Pancho_5.pkl
# got 33 total trials
# got 33 total trials
# found one matching filename: ['/data2/animals/Pancho/200226/200226_154212_pilot_Pancho_6.h5']
# found one matching filename: ['/data2/animals/Pancho/200226/200226_154212_pilot_Pancho_6.pkl']
# -- loaded presaved data: /data2/animals/Pancho/200226/200226_154212_pilot_Pancho_6.pkl
# got 19 total trials
# got 19 total trials
# found one matching filename: ['/data2/animals/Pancho/200226/200226_155332_pilot_Pancho_7.h5']
# found one matching filename: ['/data2/animals/Pancho/200226/200226_155332_pilot_Pancho_7.pkl']
# -- loaded presaved data: /data2/animals/Pancho/200226/200226_155332_pilot_Pancho_7.pkl
# got 115 total trials
# got 115 total trials
# did not find any glob match to /data2/animals/Pancho/200226/200226_*_pilot_Pancho_8.h5!!
# - No h5 file for Pancho, 200226, pilot, 8 - returning None!
# did not find any glob match to /data2/animals/Pancho/200226/200226_*_pilot_Pancho_9.h5!!
# - No h5 file for Pancho, 200226, pilot, 9 - returning None!
# did not find any glob match to /data2/animals/Pancho/200226/200226_*_pilot_Pancho_10.h5!!
# - No h5 file for Pancho, 200226, pilot, 10 - returning None!
# did not find any glob match to /data2/animals/Pancho/200226/200226_*_pilot_Pancho_11.h5!!
# - No h5 file for Pancho, 200226, pilot, 11 - returning None!
# did not find any glob match to /data2/animals/Pancho/200226/200226_*_pilot_Pancho_12.h5!!
# - No h5 file for Pancho, 200226, pilot, 12 - returning None!
# did not find any glob match to /data2/animals/Pancho/200226/200226_*_pilot_Pancho_13.h5!!
# - No h5 file for Pancho, 200226, pilot, 13 - returning None!
# did not find any glob match to /data2/animals/Pancho/200226/200226_*_pilot_Pancho_14.h5!!
# - No h5 file for Pancho, 200226, pilot, 14 - returning None!
# did not find any glob match to /data2/animals/Pancho/200226/200226_*_pilot_Pancho_15.h5!!
# - No h5 file for Pancho, 200226, pilot, 15 - returning None!
# did not find any glob match to /data2/animals/Pancho/200226/200226_*_pilot_Pancho_16.h5!!
# - No h5 file for Pancho, 200226, pilot, 16 - returning None!
# did not find any glob match to /data2/animals/Pancho/200226/200226_*_pilot_Pancho_17.h5!!
# - No h5 file for Pancho, 200226, pilot, 17 - returning None!
# did not find any glob match to /data2/animals/Pancho/200226/200226_*_pilot_Pancho_18.h5!!
# - No h5 file for Pancho, 200226, pilot, 18 - returning None!
# did not find any glob match to /data2/animals/Pancho/200226/200226_*_pilot_Pancho_19.h5!!
# - No h5 file for Pancho, 200226, pilot, 19 - returning None!
# did not find any glob match to /data2/animals/Pancho/200227/200227_*_pilot_Pancho_0.h5!!
# - No h5 file for Pancho, 200227, pilot, 0 - returning None!
# did not find any glob match to /data2/animals/Pancho/200227/200227_*_pilot_Pancho_1.h5!!
# - No h5 file for Pancho, 200227, pilot, 1 - returning None!
# did not find any glob match to /data2/animals/Pancho/200227/200227_*_pilot_Pancho_2.h5!!
# - No h5 file for Pancho, 200227, pilot, 2 - returning None!
# did not find any glob match to /data2/animals/Pancho/200227/200227_*_pilot_Pancho_3.h5!!
# - No h5 file for Pancho, 200227, pilot, 3 - returning None!
# did not find any glob match to /data2/animals/Pancho/200227/200227_*_pilot_Pancho_4.h5!!
# - No h5 file for Pancho, 200227, pilot, 4 - returning None!
# did not find any glob match to /data2/animals/Pancho/200227/200227_*_pilot_Pancho_5.h5!!
# - No h5 file for Pancho, 200227, pilot, 5 - returning None!
# did not find any glob match to /data2/animals/Pancho/200227/200227_*_pilot_Pancho_6.h5!!
# - No h5 file for Pancho, 200227, pilot, 6 - returning None!
# did not find any glob match to /data2/animals/Pancho/200227/200227_*_pilot_Pancho_7.h5!!
# - No h5 file for Pancho, 200227, pilot, 7 - returning None!
# did not find any glob match to /data2/animals/Pancho/200227/200227_*_pilot_Pancho_8.h5!!
# - No h5 file for Pancho, 200227, pilot, 8 - returning None!
# did not find any glob match to /data2/animals/Pancho/200227/200227_*_pilot_Pancho_9.h5!!
# - No h5 file for Pancho, 200227, pilot, 9 - returning None!
# did not find any glob match to /data2/animals/Pancho/200227/200227_*_pilot_Pancho_10.h5!!
# - No h5 file for Pancho, 200227, pilot, 10 - returning None!
# did not find any glob match to /data2/animals/Pancho/200227/200227_*_pilot_Pancho_11.h5!!
# - No h5 file for Pancho, 200227, pilot, 11 - returning None!
# did not find any glob match to /data2/animals/Pancho/200227/200227_*_pilot_Pancho_12.h5!!
# - No h5 file for Pancho, 200227, pilot, 12 - returning None!
# did not find any glob match to /data2/animals/Pancho/200227/200227_*_pilot_Pancho_13.h5!!
# - No h5 file for Pancho, 200227, pilot, 13 - returning None!
# did not find any glob match to /data2/animals/Pancho/200227/200227_*_pilot_Pancho_14.h5!!
# - No h5 file for Pancho, 200227, pilot, 14 - returning None!
# did not find any glob match to /data2/animals/Pancho/200227/200227_*_pilot_Pancho_15.h5!!
# - No h5 file for Pancho, 200227, pilot, 15 - returning None!
# did not find any glob match to /data2/animals/Pancho/200227/200227_*_pilot_Pancho_16.h5!!
# - No h5 file for Pancho, 200227, pilot, 16 - returning None!
# did not find any glob match to /data2/animals/Pancho/200227/200227_*_pilot_Pancho_17.h5!!
# - No h5 file for Pancho, 200227, pilot, 17 - returning None!
# did not find any glob match to /data2/animals/Pancho/200227/200227_*_pilot_Pancho_18.h5!!
# - No h5 file for Pancho, 200227, pilot, 18 - returning None!
# did not find any glob match to /data2/animals/Pancho/200227/200227_*_pilot_Pancho_19.h5!!
# - No h5 file for Pancho, 200227, pilot, 19 - returning None!

# %%
# find case that are:
behtype = "Trace (instant)"
taskstages = ["two_lines_natural", "two_lines"]
taskstages = ["two_lines_anywhere"]

for out in outdict:
    
    if [o for o, N in out["taskstages"].items() if o in taskstages]:
        print(f"{out['date']} - {out['expt']} - {out['sess']}")
        print(set([o for o in out["behtype_trials"]]))
        [print(f"{o} - {N}") for o, N in out["taskstages"].items() if o in taskstages]
    
#     [print(f"{o} - {N}") for o, N in out["taskstages"].items() if o==taskstages]
# Out:
# 200226 - pilot - 1
# {'Trace (instant)', 'Trace (pursuit,track)'}
# two_lines_anywhere - 256
# 200226 - pilot - 3
# {'Trace (instant)'}
# two_lines_anywhere - 83

# %%
animal = "Pancho";
date = 200226
expt = "pilot"
session = 1

from tools.preprocess import *
filedata = loadSingleData(animal, date, expt, session, resave_as_dict=False, load_resaved_data=True, 
                      resave_overwrite=False)

from tools.utils import *
getMultTrialsTaskStages(filedata)
# Out:
# found one matching filename: ['/data2/animals/Pancho/200226/200226_121930_pilot_Pancho_1.h5']
# found one matching filename: ['/data2/animals/Pancho/200226/200226_121930_pilot_Pancho_1.pkl']
# -- loaded presaved data: /data2/animals/Pancho/200226/200226_121930_pilot_Pancho_1.pkl
# got 617 total trials
# {'circle_partial': 172,
#  'two_lines_anywhere': 256,
#  'line_natural': 6,
#  'line': 116,
#  'one_dot': 28,
#  'two_lines_natural': 20,
#  'three_lines_natural': 19}
