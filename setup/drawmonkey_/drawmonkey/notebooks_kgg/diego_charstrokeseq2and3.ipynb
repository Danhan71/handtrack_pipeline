# %% [markdown]
# ## 1. install pythonlib + libraries

# %%
# %load_ext autoreload
# %autoreload 2

# %%
### install pythonlib + dependencies ###

import os
os.chdir('/Users/kdu/Desktop/rockefeller/pythonlib')
# %pip install ../pythonlib

#!{sys.executable} -m pip install ./pythonlib
#!{sys.executable} -m pip install imageio
#!{sys.executable} -m pip install pickle5

#import sys
#sys.path.append('.')
#sys.path.append('~/Desktop/rockefeller/pythonlib')
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Processing /Users/kdu/Desktop/rockefeller/pythonlib
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pythonlib: filename=pythonlib-1.0-py3-none-any.whl size=975 sha256=538d155d8fe91ca0a25dea761b53ac26bd685617262d0049b9edbd536ce98d13
#   Stored in directory: /private/var/folders/g8/bh23cq4552q22_hz8xtv34jm0000gp/T/pip-ephem-wheel-cache-oc7cbgn_/wheels/f1/82/ba/7e37154ccb9c8fc6c97346c8690ca81fe55e01015a59105b67
# Successfully built pythonlib
# ...
#   Attempting uninstall: pythonlib
#     Found existing installation: pythonlib 1.0
#     Uninstalling pythonlib-1.0:
#       Successfully uninstalled pythonlib-1.0
# ...

# %%
import os
import pickle
import matplotlib.pyplot as plt
import seaborn as sns

import pythonlib
from pythonlib.drawmodel.analysis import *
from pythonlib.tools.stroketools import *
from pythonlib.dataset.dataset import Dataset

# %% [markdown]
# ## 2. single day: 220929

# %% [markdown]
# #### Load data

# %%
# load data
from pythonlib.dataset.dataset_preprocess.general import get_rulelist

expt = "charstrokeseq2"
animal = "Diego"
rulelist = ["220929"] # rulelist = get_rulelist(animal, expt)
D = Dataset([])

D.load_dataset_helper(animal, expt, ver="mult", rule=rulelist)

#from pythonlib.dataset.dataset_preprocess.general import preprocessDat
#D._analy_preprocess_done = False
#D, GROUPING, GROUPING_LEVELS, FEATURE_NAMES, SCORE_COL_NAMES = preprocessDat(D, expt)

# %% [markdown]
# ####  Plot: Nbeh_strokes v. Ntask_strokes (matplotlib)

# %%
# select all test tasks
n_data = D.Dat[D.Dat['monkey_train_or_test']=='test']

# for this specific expt, there are char_star, char tasks
# we just want char_star, which comes from sets 15-18
n_data = n_data[n_data['task_stagecategory'].str.contains("ss-1[5-8]")]

# plot num_strokes vs len(strokes_task)
n_data['beh_strokes_count'] = n_data['strokes_beh'].apply(len)
n_data['task_strokes_count'] = n_data['strokes_task'].apply(len)

plt.scatter(n_data['task_strokes_count'],n_data['beh_strokes_count'],alpha=0.5,marker="o")

# %% [markdown]
# ####  Plot: Nbeh_strokes v. Ntask_strokes (seaborn)

# %%
import seaborn as sns

sns.catplot(data=n_data,x='task_strokes_count',y='beh_strokes_count',kind='violin')
fig,axes=plt.subplots(1,1)
sns.regplot(data=n_data,x='task_strokes_count',y='beh_strokes_count',ax=axes)
axes.set_xlim([1,6])
axes.set_ylim([1,6])

# %% [markdown]
# ## 3. all charstrokeseq2,3: 220929-221005

# %% [markdown]
# #### Load data

# %%
from pythonlib.dataset.dataset_preprocess.general import get_rulelist

expt = "charstrokeseq23"
animal = "Diego"
rulelist = ["null"] # rulelist = get_rulelist(animal, expt)
D = Dataset([])

D.load_dataset_helper(animal, expt, ver="mult", rule=rulelist)
# Out:
# Searching using this string:
# /Volumes/kdot/analyses/database/*Diego-*charstrokeseq23-*null-*/*dat*.pkl
# -- Splitting off dir from fname
# Found this many paths:
# 0
# Searching using this string:
# /Volumes/kdot/analyses/database/BEH/*Diego-*charstrokeseq23-*null-*/*dat*.pkl
# -- Splitting off dir from fname
# Found this many paths:
# 1
# ---
# /Volumes/kdot/analyses/database/BEH/Diego-charstrokeseq23-null-221027_174413
# ----------------
# Currently loading dataset pkl: /Volumes/kdot/analyses/database/BEH/Diego-charstrokeseq23-null-221027_174413
# .. Done!
# Loaded metadat:
# {'sketchpad_edges': array([[-311.84, -224.8 ],
# ...

# %% [markdown]
# #### Plot: Nbeh_strokes v. Ntask_strokes (matplotlib)

# %%
## select all test tasks
n_data = D.Dat[D.Dat['monkey_train_or_test']=='test']

## for this specific expt, there are char_star, char tasks
## we just want char_star, which comes from sets 15-18 (NOTE: only true for 220929...figure out for rest of days)
###n_data = n_data[n_data['task_stagecategory'].str.contains("ss-1[5-8]")]

## plot num_strokes vs len(strokes_task)
n_data['beh_strokes_count'] = n_data['strokes_beh'].apply(len)
n_data['task_strokes_count'] = n_data['strokes_task'].apply(len)

plt.scatter(n_data['task_strokes_count'],n_data['beh_strokes_count'],alpha=0.5,marker="o")
# Out:
# <ipython-input-32-57aa0917a6bf>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   n_data['beh_strokes_count'] = n_data['strokes_beh'].apply(len)
# <ipython-input-32-57aa0917a6bf>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   n_data['task_strokes_count'] = n_data['strokes_task'].apply(len)

# %%
# plot delta per day
n_data['stroke_delta'] = n_data['task_strokes_count'] - n_data['beh_strokes_count']

plt.scatter(n_data['stroke_delta'],n_data['date_epoch'],alpha=0.5,marker="o")
# Out:
# <ipython-input-34-2db1a7e2ef0b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   n_data['stroke_delta'] = n_data['task_strokes_count'] - n_data['beh_strokes_count']

# %% [markdown]
# ####  Plot: Nbeh_strokes v. Ntask_strokes (seaborn)

# %%
import seaborn as sns

sns.catplot(data=n_data,x='task_strokes_count',y='beh_strokes_count',kind='violin')
fig,axes=plt.subplots(1,1)
sns.regplot(data=n_data,x='task_strokes_count',y='beh_strokes_count',ax=axes)
axes.set_xlim([1,6])
axes.set_ylim([1,6])
# Out:
# (1.0, 6.0)

# %% [markdown]
# ### Part 2 - secondary analysis on length/angle regularization

# %%
# extract aligned {beh_strokes, task_strokes}
D.behclass_preprocess_wrapper()

# %%
#beh_strokes_count
trial = 117
D.plotSingleTrial(trNial)

strk_align = D.behclass_extract_beh_and_task(trial)[3] # task strokes, matched to beh stroke index
beh_strk = strk_align[1][1]
task_strk = strk_align[1][2]

beh_strk[0]() # beh_strk data
task_strk['Prim'].Stroke() # task_strk data

### compute angle - see luca
