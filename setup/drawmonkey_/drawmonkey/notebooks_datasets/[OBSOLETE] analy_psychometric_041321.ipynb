# %%
""" 
integrate tasks and beh into Dataset class.
For psychometric, make plots ordered along axes.
Also make summaries (scalar stat vs. position along axis)

"""
# Out:
# ' \nintegrate tasks and beh into Dataset class.\nFor psychometric, make plots ordered along axes.\nAlso make summaries (scalar stat vs. position along axis)\n\n'

# %%
from pythonlib.dataset.dataset import Dataset
import pickle

# %cd ..
from tools.utils import * 
from tools.plots import *
from tools.analy import *
from tools.calc import *
from tools.analyplot import *
from tools.preprocess import *
from tools.dayanalysis import *

from pythonlib.drawmodel.analysis import *
from pythonlib.tools.stroketools import *
# Out:
# /data1/code/python/drawmonkey
# NOTE: need to not overwrite strokes_all_task, because then the orders saved will stop being accurate. Modify

# %%
# Load dataset
from pythonlib.dataset.dataset import Dataset

animal = "Pancho"
expt = "lines5"

D = Dataset([])
D.load_dataset_helper(animal, expt)
# Out:
# Did not load data!!!
# Searching using this string:
# /data2/analyses/database//*Pancho*lines5*/*dat*.pkl
# -- Splitting off dir from fname
# Found this many paths:
# 1
# ---
# /data2/analyses/database/Pancho-lines5-formodeling-210329_014835
# Searching using this string:
# /data2/analyses/database/BEH/*Pancho*lines5*/*dat*.pkl
# -- Splitting off dir from fname
# Found this many paths:
# 0
# ----------------
# Currently loading: /data2/analyses/database/Pancho-lines5-formodeling-210329_014835
# Loaded metadat:
# {'sketchpad_edges': array([[-327.2, -327.2],
#        [ 327.2,  429.6]])}
# ----
# Resetting index
# === CLEANING UP self.Dat =====
# ORIGINAL: online abort values
# Series([], Name: online_abort, dtype: int64)
# kept 6949 out of 6949
# removed all cases with online abort not None
# Deleted unused columns from self.Dat

# %%
# del D.Dat["Task"]
D.load_tasks_helper()
# Out:
# Searching using this string:
# /data2/analyses/database/TASKS_GENERAL/Pancho-lines2-all/*Tasks*pkl
# Found this many paths:
# 1
# ---
# /data2/analyses/database/TASKS_GENERAL/Pancho-lines2-all/Tasks.pkl
# added new column self.Dat[Task]

# %% [markdown]
# ### PLOT, PSYCHOMETRIC

# %% [markdown]
# #### 1) Grid plot, organized by task variation

# %%
sdir = f"/data2/analyses/main/psychometric/monkey/{animal}-{expt}/plots"
os.makedirs(sdir, exist_ok=True)
from pythonlib.dataset.psychometric import plotMultTaskcategories
for max_n_per_grid in [None] + list(range(5)):
    sdirthis = f"{sdir}/npergrid_{max_n_per_grid}"
    os.makedirs(sdirthis, exist_ok=True)
    plotMultTaskcategories(D, sdir=sdirthis, max_n_per_grid=max_n_per_grid)
# Out:
# Plotting these cats:
# ['3line_psych1', '3line_psych2', '3line_psych3', '3line_psych5', '3line_psych6']
# Saved 3line_psych1 to /data2/analyses/main/psychometric/monkey/Pancho-lines2/plots/npergrid_None
# Saved 3line_psych2 to /data2/analyses/main/psychometric/monkey/Pancho-lines2/plots/npergrid_None
# Saved 3line_psych3 to /data2/analyses/main/psychometric/monkey/Pancho-lines2/plots/npergrid_None
# Saved 3line_psych5 to /data2/analyses/main/psychometric/monkey/Pancho-lines2/plots/npergrid_None
# Saved 3line_psych6 to /data2/analyses/main/psychometric/monkey/Pancho-lines2/plots/npergrid_None
# Plotting these cats:
# ['3line_psych1', '3line_psych2', '3line_psych3', '3line_psych5', '3line_psych6']
# Saved 3line_psych1 to /data2/analyses/main/psychometric/monkey/Pancho-lines2/plots/npergrid_0
# Saved 3line_psych2 to /data2/analyses/main/psychometric/monkey/Pancho-lines2/plots/npergrid_0
# Saved 3line_psych3 to /data2/analyses/main/psychometric/monkey/Pancho-lines2/plots/npergrid_0
# Saved 3line_psych5 to /data2/analyses/main/psychometric/monkey/Pancho-lines2/plots/npergrid_0
# Saved 3line_psych6 to /data2/analyses/main/psychometric/monkey/Pancho-lines2/plots/npergrid_0
# Plotting these cats:
# ['3line_psych1', '3line_psych2', '3line_psych3', '3line_psych5', '3line_psych6']
# /data1/code/python/pythonlib/pythonlib/tools/plottools.py:486: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nr, nc, sharex=True, sharey=True,
# Saved 3line_psych1 to /data2/analyses/main/psychometric/monkey/Pancho-lines2/plots/npergrid_1
# Saved 3line_psych2 to /data2/analyses/main/psychometric/monkey/Pancho-lines2/plots/npergrid_1
# Saved 3line_psych3 to /data2/analyses/main/psychometric/monkey/Pancho-lines2/plots/npergrid_1
# Saved 3line_psych5 to /data2/analyses/main/psychometric/monkey/Pancho-lines2/plots/npergrid_1
# Saved 3line_psych6 to /data2/analyses/main/psychometric/monkey/Pancho-lines2/plots/npergrid_1
# Plotting these cats:
# ['3line_psych1', '3line_psych2', '3line_psych3', '3line_psych5', '3line_psych6']
# Saved 3line_psych1 to /data2/analyses/main/psychometric/monkey/Pancho-lines2/plots/npergrid_2
# Saved 3line_psych2 to /data2/analyses/main/psychometric/monkey/Pancho-lines2/plots/npergrid_2
# Saved 3line_psych3 to /data2/analyses/main/psychometric/monkey/Pancho-lines2/plots/npergrid_2
# Saved 3line_psych5 to /data2/analyses/main/psychometric/monkey/Pancho-lines2/plots/npergrid_2
# Saved 3line_psych6 to /data2/analyses/main/psychometric/monkey/Pancho-lines2/plots/npergrid_2
# Plotting these cats:
# ['3line_psych1', '3line_psych2', '3line_psych3', '3line_psych5', '3line_psych6']
# Saved 3line_psych1 to /data2/analyses/main/psychometric/monkey/Pancho-lines2/plots/npergrid_3
# Saved 3line_psych2 to /data2/analyses/main/psychometric/monkey/Pancho-lines2/plots/npergrid_3
# Saved 3line_psych3 to /data2/analyses/main/psychometric/monkey/Pancho-lines2/plots/npergrid_3
# Saved 3line_psych5 to /data2/analyses/main/psychometric/monkey/Pancho-lines2/plots/npergrid_3
# Saved 3line_psych6 to /data2/analyses/main/psychometric/monkey/Pancho-lines2/plots/npergrid_3
# Plotting these cats:
# ['3line_psych1', '3line_psych2', '3line_psych3', '3line_psych5', '3line_psych6']
# Saved 3line_psych1 to /data2/analyses/main/psychometric/monkey/Pancho-lines2/plots/npergrid_4
# Saved 3line_psych2 to /data2/analyses/main/psychometric/monkey/Pancho-lines2/plots/npergrid_4
# Saved 3line_psych3 to /data2/analyses/main/psychometric/monkey/Pancho-lines2/plots/npergrid_4
# Saved 3line_psych5 to /data2/analyses/main/psychometric/monkey/Pancho-lines2/plots/npergrid_4
# Saved 3line_psych6 to /data2/analyses/main/psychometric/monkey/Pancho-lines2/plots/npergrid_4

# %%
# each task extract its number


# update grid plot code to work with strokes list

# %% [markdown]
# #### 2) compute some scalar score
